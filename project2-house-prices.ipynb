# %% [markdown]
# Project 2: Scraping apartment sales prices
#
# Name: Veera Tegelberg
# Email: veera.tegelberg@gmail.com
# GitHub: TegelVee
#
# This project is part of Columbia University's Lede Program 2024. In the project I will be scraping housing prices in Helsinki metropolitan area from Asuntojen hintatiedot webpage: https://asuntojen.hintatiedot.fi/haku/. The page gathers sales prices from real estate brokers and is maintained by a public office.
#
# Data limitations
# - the data does not encompass all houses that have been sold
# - sales date is not reported, so shortterm comparison is not possible
# - information stays on the page for 12 months, so neather longterm comparison is possible
# - data does not include postalcodes, only name of the are, which is as an information less trustworthy than postalcode
#
# Due to these limitations, data must be seen as directional snapshot of local housing market

# %% [markdown]
# PART 1: SCRAPING THE DATA

# %%
#Bring libraries that I need.
import requests
import pandas as pd
from bs4 import BeautifulSoup
from random import randint 
from time import sleep

# %%
#scrape the first webpage and turn it into a bs4 object

url = "https://asuntojen.hintatiedot.fi/haku/?c=Helsinki&cr=1&t=3&l=2&z=1&search=1&sf=0&so=a&renderType=renderTypeTable&print=0&submit=Next+page"
html = requests.get(url).text
soup = BeautifulSoup(html)
#soup

# %%
# Base URL with a placeholder for the 'z' parameter
base_url = "https://asuntojen.hintatiedot.fi/haku/?c=Helsinki&cr=1&t=3&l=2&z={}&search=1&sf=0&so=a&renderType=renderTypeTable&print=0&submit=Next+page"

collected_data = []

# Set range from 1 to 48 to go through all tabs that hold information about house prices.
for z in range(1, 48):
    # Format the URL with the current value of 'z'
    url = base_url.format(z)
    
    # Send an HTTP request to the URL
    # The URL is formated with base_url and by changing the z with different number while for looping
    response = requests.get(url)
    
    # Check if the request was successful
    if response.status_code == 200:
        # Parse the HTML content
        soup = BeautifulSoup(response.content, 'html.parser')
        
        # Extract the data from table rows (tr)
        # This does not collect the headerline
        table_rows = soup.find_all('tr')
        
        # Here information of each row is put into a list with for loop
        for row in table_rows:
            # td referring to each table cell
            columns = row.find_all('td')
            # Taking all whitespaces away with strip
            data = [column.get_text(strip=True) for column in columns]
            # append needed to get all rows into a one list
            collected_data.append(data)

    # Precaution just in case the data is not found        
    else:
        print(f"Failed to retrieve page {z}")

    # A delay, so the server will not be overloaded
    # It takes around 2 minutes to collect the data
    import time
    time.sleep(2)

print("Collected data:")
for data in collected_data:
    print(data)
# Out:
# Collected data:
# []
# ['1', '', '1', '']
# ['', '1', '']
# ['Studio apartment']
# ['Itä-pasila', '1h,kt,alkovi', 'kt', '34,00', '283000', '8324', '2020', '3/6', 'yes', 'good', 'own', 'C2013']
# ['Kallio', '1h+k+alkovi+kph', 'kt', '37,50', '276000', '7360', '1926', '4/7', 'yes', 'good', 'own', 'F2013']
# ['Tapaninvainio', '1h, kk, kh, ter...', 'kt', '24,00', '64000', '2667', '1964', '1/2', 'no', 'average', 'own', 'G2013']
# ['Kallio', '1h, kk, kph, vh', 'kt', '28,00', '170000', '6071', '1962', '4/7', 'yes', 'good', 'own', 'D2018']
# ['Hakaniemi', '1h+k', 'kt', '36,00', '190000', '5278', '1989', '2/8', 'yes', '', 'own', 'F2018']
# ['Taka-töölö', '1h, avok, kph', 'kt', '20,50', '156000', '7610', '1939', '1/6', 'yes', 'good', 'own', 'D2018']
# ['Lauttasaari', '1h+kk+vh+kph+la...', 'kt', '25,50', '215000', '8431', '1961', '2/5', 'yes', 'good', 'own', 'C2018']
# ['Kallio', '1h, avok, kph, wc', 'kt', '26,60', '160000', '6015', '1929', '1/6', 'yes', 'good', 'own', 'D2018']
# ['Kallio', '1h+kk', 'kt', '29,00', '158500', '5466', '1932', '5/7', 'yes', 'average', 'own', 'E2018']
# ['Lauttasaari', '1h, avok', 'kt', '29,50', '172000', '5831', '1954', '2/4', 'no', 'average', 'own', 'D2018']
# ['Alppikylä', '1h+k+varasto', 'rt', '38,00', '170000', '4474', '2019', '1/1', 'no', 'good', 'rent', 'C2013']
# ['Herttoniemi', '1 h, kk, kph', 'kt', '22,00', '81700', '3714', '1956', '1/2', 'no', 'average', 'rent', 'E2018']
# ['Etelä-haaga', '1h, kk', 'kt', '26,00', '129000', '4962', '1963', '1/3', 'no', 'good', 'own', 'E2018']
# ['Alppila', '1h +avok. + kph...', 'kt', '30,80', '180000', '5844', '1938', '1/4', 'no', 'good', 'own', 'F2013']
# ['Lauttasaari', '1h+kk', 'kt', '32,00', '155845', '4870', '1976', '2/6', 'yes', 'poor', 'own', 'D2007']
# ['Laajasalo', '1 h, kk, kph, p', 'kt', '25,00', '120000', '4800', '1966', '3/5', 'yes', 'average', 'own', 'E2018']
# ['Vuosaari', '1h,avok,alk,kh,...', 'kt', '43,00', '226500', '5267', '2016', '5/5', 'yes', 'good', 'own', 'C2013']
# ['Punavuori', '1h+k+kph', 'kt', '45,00', '296300', '6584', '1923', '5/5', 'no', 'average', 'own', 'D2018']
# ['Aurinkolahti', '1h+kk+alkovi+kp...', 'kt', '45,50', '231000', '5077', '2005', '7/8', 'yes', 'good', 'own', 'B2018']
# ['Ullanlinna', '1h,avokeittiö', 'kt', '22,00', '185000', '8409', '1912', '2/5', 'yes', 'good', 'own', '']
# ['Alppiharju', '1h+kph', 'kt', '28,00', '172500', '6161', '1928', '3/7', 'yes', 'average', 'own', 'F2013']
# ['Puotila', '1h, kk, alk, vh...', 'kt', '27,00', '109000', '4037', '1961', '2/3', 'no', 'good', 'rent', '']
# ['Munkkiniemi', '1h, alk, kk, kp...', 'kt', '33,00', '228000', '6909', '1954', '4/4', 'yes', 'average', 'own', '']
# ['Vallila', '1h+k', 'kt', '48,00', '200000', '4167', '1926', '3/4', 'no', 'average', 'rent', 'F2018']
# ['Vuosaari', '1h+alk+kk+s+ la...', 'kt', '34,00', '132000', '3882', '2000', '4/8', 'yes', 'good', 'own', 'G2007']
# ['Malmi', '1h, kk, kph', 'kt', '27,50', '95000', '3455', '1964', '2/3', 'no', 'average', 'own', 'F2013']
# ['Sörnäinen', '1 h, kt, rt, al...', 'kt', '37,00', '228000', '6162', '1938', '4/8', 'yes', 'good', 'own', 'E2018']
# ['Ullanlinna', '1h, kk, kph', 'kt', '24,10', '177500', '7365', '1907', '-1/3', 'no', 'average', 'own', 'F2014']
# ['Lauttasaari', '1h, k, alkovi, ...', 'kt', '26,10', '205000', '7854', '1978', '2/2', 'no', 'good', 'own', 'F2007']
# ['Herttoniemi', '1h+kt+lasit. pa...', 'kt', '30,00', '198000', '6600', '2017', '2/8', 'yes', 'good', 'own', 'C2013']
# ['Alppiharju', '1h, k, kph', 'kt', '42,00', '227000', '5405', '1951', '6/6', 'yes', 'good', 'own', 'G2013']
# ['Punavuori', '1h, kk, kph, vh', 'kt', '27,50', '221278', '8046', '1961', '7/7', 'yes', 'good', 'own', 'F2013']
# ['Vallila', '1 h+k+kph', 'kt', '28,00', '165750', '5920', '1938', '3/5', 'yes', 'average', 'own', 'E2018']
# ['Maunula', '1h, ikkunalline...', 'kt', '34,50', '125000', '3623', '1972', '2/4', 'yes', 'average', 'rent', 'E2013']
# ['Punavuori', '1h, kk, kph', 'kt', '23,00', '212000', '9217', '1908', '4/5', 'yes', 'average', 'own', '']
# ['Alppila', '1h + kk + kph +...', 'kt', '29,00', '175000', '6034', '1960', '6/8', 'yes', 'good', 'own', 'F2018']
# ['Kontula', '1h, kk, kph(wc', 'kt', '28,00', '87000', '3107', '1967', '2/3', 'no', 'average', 'rent', '']
# ['Kallio', '1-2 h+et+kph', 'kt', '33,00', '180000', '5455', '1926', '1/3', 'no', 'average', 'own', 'G2013']
# ['Vallila', '1h + k + kph', 'kt', '36,80', '174000', '4728', '1966', '1/3', 'no', 'good', 'rent', 'G2013']
# ['Alppiharju', '1h, kk, kph', 'kt', '25,00', '161000', '6440', '1928', '2/7', 'yes', 'good', 'own', 'F2013']
# ['Munkkiniemi', '1h, kk, kph, vh', 'kt', '26,00', '182500', '7019', '1938', '4/6', 'yes', 'good', 'own', 'D2018']
# ['Aurinkolahti', '1h, kk, kä...', 'kt', '37,50', '163500', '4360', '2006', '1/3', 'yes', 'good', 'own', 'D2013']
# ['Kamppi', '1h,k,kph', 'kt', '42,00', '325000', '7738', '1908', '3/4', 'no', 'average', 'own', 'D2007']
# ['Kallio', '1h,kk', 'kt', '23,00', '140000', '6087', '1929', '4/4', 'yes', 'good', 'own', '']
# ['Kallio', '1h+kk+kph', 'kt', '24,00', '167000', '6958', '1926', '7/7', 'yes', 'average', 'own', 'D2018']
# ['Lauttasaari', '1h, kt, kph, la...', 'kt', '29,50', '173000', '5864', '1973', '6/9', 'yes', 'good', 'own', 'C2018']
# ['Kallio', '1h, avok, kph, ...', 'kt', '37,00', '230000', '6216', '1939', '4/7', 'yes', 'good', 'own', 'E2013']
# ['Etelä-haaga', '1h, k, kph, par...', 'kt', '26,00', '148000', '5692', '1961', '3/3', 'no', 'good', 'own', 'E2018']
# ['Harju', '1h+avok.+parvi+kph', 'kt', '27,00', '177000', '6556', '1936', '2/3', 'yes', 'good', 'own', 'G2013']
# ['Lauttasaari', '1h+kk+kph+las.p...', 'kt', '34,00', '230000', '6765', '1977', '1/4', 'yes', 'good', 'own', 'C2018']
# ['Etu-töölö', '1h, kk, kph/wc,...', 'kt', '24,90', '203000', '8153', '1935', '3/7', 'yes', 'good', 'own', 'D2018']
# ['Vallila', '1h, avok ja kph', 'kt', '30,50', '185000', '6066', '1927', '2/3', 'no', 'average', 'own', 'G2013']
# ['1', '', '1', '']
# ['', '1', '']
# []
# ['2', '', '2', '']
# ['', '2', '']
# ['Studio apartment']
# ['Taka-töölö', '1h+alk+kk+kph', 'kt', '26,00', '180000', '6923', '1955', '3/8', 'yes', 'average', 'rent', 'D2018']
# ['Sörnäinen', '1h, kk, kph, s, p', 'kt', '33,00', '142396', '4315', '1986', '4/5', 'yes', 'poor', 'own', 'E2013']
# ['Alppila', '1h, k, kph, alk...', 'kt', '39,00', '270000', '6923', '1920', '5/7', 'yes', 'good', 'own', 'F2013']
# ['Kontula', '1h+alkovi+k+kph', 'kt', '25,50', '85000', '3333', '1967', '1/4', 'no', 'average', 'own', 'G']
# ['Meilahti', '1h, kk', 'kt', '20,00', '128000', '6400', '1938', '1/4', 'no', 'good', 'own', 'D2018']
# ['Munkkivuori', '1h,kk', 'kt', '24,70', '125000', '5061', '1957', '3/6', 'no', 'good', 'rent', 'G2013']
# ['Etelä-haaga', '1h, alkovi, kk,...', 'kt', '27,00', '170000', '6296', '1959', '3/3', 'no', 'good', 'own', 'F2018']
# ['Kannelmäki', '1h, kk, kph/wc,...', 'kt', '30,00', '120000', '4000', '1960', '1/4', 'no', 'good', 'own', 'E2007']
# ['Alppila', '1 h + kk', 'kt', '34,80', '216000', '6207', '1928', '6/6', 'yes', 'average', 'own', 'E2013']
# ['Pohjois-haaga', '1h, kk, vh, kph', 'kt', '34,00', '105000', '3088', '1954', '2/4', 'no', 'average', 'own', 'G2018']
# ['Hernesaari', '1h, k, kph', 'kt', '38,00', '310000', '8158', '1912', '4/5', 'no', 'average', 'own', '']
# ['Taka-töölö', '1 h + kk + alko...', 'kt', '35,00', '270000', '7714', '1936', '5/6', 'yes', 'good', 'own', 'F2013']
# ['Oulunkylä', '1 h, kk, kph, l...', 'kt', '24,00', '105000', '4375', '1964', '2/3', 'no', 'average', 'own', 'G2013']
# ['Ullanlinna', '1h, k, kph', 'kt', '28,00', '229000', '8179', '1929', '1/4', 'yes', 'average', 'own', 'F2013']
# ['Kruununhaka', '1h, avok, kph, ...', 'kt', '28,50', '329000', '11544', '1861', '3/5', 'no', 'good', 'own', '']
# ['Puotila', '1h, kk', 'kt', '33,00', '106000', '3212', '1960', '3/3', 'no', 'good', 'rent', 'D2007']
# ['Kallio', '1h+avokeitti\x02...', 'kt', '30,50', '195000', '6393', '1927', '3/5', 'yes', 'good', 'own', 'C2018']
# ['Etu-töölö', '1h, kk, kph', 'kt', '33,00', '181000', '5485', '1938', '3/6', 'yes', 'poor', 'own', 'G2013']
# ['Ullanlinna', '1h, kk, kph', 'kt', '24,00', '183770', '7657', '1937', '4/4', 'no', 'good', 'own', 'E2018']
# ['Kallio', '1h+kk+kph', 'kt', '32,00', '208000', '6500', '1928', '6/6', 'yes', '', 'own', 'F2013']
# ['Punavuori', '1h, kk, kph, la...', 'kt', '26,00', '218000', '8385', '1961', '2/6', 'yes', 'good', 'own', 'E2013']
# ['Töölö', '1h+kph+avokeitt...', 'kt', '26,50', '209000', '7887', '1923', '1/6', 'yes', 'average', 'own', 'D']
# ['Kulosaari', '1h, avokeitti&#...', 'kt', '26,60', '166500', '6259', '1961', '2/3', 'no', 'good', 'own', 'F2013']
# ['Munkkiniemi', '1 h, k, vh, kph...', 'kt', '27,00', '167400', '6200', '1960', '1/6', 'yes', 'good', 'own', 'E2018']
# ['Lauttasaari', '1h+kk+kph', 'kt', '28,00', '193000', '6893', '1961', '1/5', 'yes', 'good', 'own', 'D2018']
# ['Pohjois-haaga', '1h, k, kph, p', 'kt', '30,00', '150000', '5000', '1952', '5/7', 'yes', 'average', 'own', 'E2018']
# ['Kallio', '1h, avok', 'kt', '19,00', '158000', '8316', '1938', '5/7', 'yes', 'good', 'own', 'F2007']
# ['Lauttasaari', '1 h+kk+kph', 'kt', '21,00', '189000', '9000', '1961', '3/4', 'yes', 'good', 'own', 'F2013']
# ['Hietalahti', '1h, et, k, kph,...', 'kt', '23,00', '230000', '10000', '1961', '8/8', 'yes', 'good', 'own', 'E2018']
# ['Malmi', '1 h, k, kh/wc, ...', 'kt', '35,00', '91950', '2627', '1983', '3/3', 'no', 'average', 'rent', 'E2007']
# ['Kallio', '1h, avok', 'kt', '19,00', '158000', '8316', '1938', '2/7', 'yes', 'good', 'own', 'F2007']
# ['Meilahti', '1h+kk', 'kt', '20,00', '142500', '7125', '1946', '4/7', 'yes', 'average', 'own', 'F2007']
# ['Ullanlinna', '1h, kk, kph', 'kt', '24,00', '195000', '8125', '1937', '5/7', 'no', 'average', 'own', 'E2018']
# ['Hakaniemi', '1h+kk', 'kt', '24,30', '175500', '7222', '1940', '5/7', 'yes', 'poor', 'own', 'E2013']
# ['Malmi', '1h, kk, kph, ra...', 'kt', '29,00', '110000', '3793', '1965', '1/3', 'no', 'average', 'own', 'F2013']
# ['Sörnäinen', '1h+k+kph', 'kt', '32,00', '190000', '5938', '1929', '6/8', 'yes', 'good', 'own', 'F2013']
# ['Mellunmäki', '1h, kk, kph, p', 'kt', '34,50', '105000', '3043', '1976', '2/3', 'no', 'average', 'own', 'E2018']
# ['Alppila', '1h+avok.+alkovi...', 'kt', '36,80', '202000', '5489', '1928', '2/6', 'yes', 'good', 'own', 'E2013']
# ['Etu-töölö', '1h, avok, kph, ...', 'kt', '24,00', '238000', '9917', '1927', '1/6', 'yes', 'good', 'own', 'E2018']
# ['Etu-töölö', '1h, kk, kph', 'kt', '28,90', '268000', '9273', '1924', '6/6', 'yes', 'average', 'own', 'F2013']
# ['Taka-töölö', '1h+k', 'kt', '39,00', '269000', '6897', '1929', '4/6', 'yes', 'average', 'own', 'D2018']
# ['Itä-pasila', '1h+kk+kh', 'kt', '32,00', '102000', '3188', '1974', '2/13', 'yes', 'average', 'rent', 'G2013']
# ['Oulunkylä', '1h+kk', 'kt', '34,30', '65000', '1895', '1975', '1/3', 'no', 'good', 'rent', 'D2018']
# ['Harju', '1h, kk, kph', 'kt', '23,00', '153000', '6652', '1956', '6/6', 'yes', 'average', 'own', 'F2013']
# ['Kannelmäki', '1h, kk, kph', 'kt', '31,00', '110000', '3548', '1962', '1/3', 'no', 'average', 'own', 'F2013']
# ['Taka-töölö', '1h, avok, kph (...', 'kt', '40,60', '260000', '6404', '1913', '5/5', 'no', 'average', 'own', 'D2013']
# ['Käpylä', '1h, k, alk.ovi,...', 'kt', '31,00', '176000', '5677', '1941', '3/3', 'no', 'good', 'rent', 'G2013']
# ['Lauttasaari', '1h, kk, kph, ra...', 'kt', '29,50', '198000', '6712', '1955', '1/4', 'no', 'good', 'own', 'D2018']
# ['Etu-töölö', '1h, avok., kph, vh', 'kt', '28,50', '251370', '8820', '1930', '8/8', 'yes', 'good', 'own', 'F2013']
# ['Kalasatama', '1h+kt+parvi', 'kt', '29,50', '310130', '10513', '2021', '7/16', 'yes', 'good', 'own', 'B2018']
# ['Etelä-haaga', '1h,k,kph', 'kt', '40,50', '220000', '5432', '1940', '2/3', 'no', 'average', 'own', 'F2013']
# ['Kamppi', '1h, kk', 'kt', '32,00', '180000', '5625', '1939', '2/5', 'yes', 'poor', 'own', 'F2013']
# ['2', '', '2', '']
# ['', '2', '']
# []
# ['3', '', '3', '']
# ['', '3', '']
# ['Studio apartment']
# ['Ullanlinna', '1h, alkovi, kei...', 'kt', '34,90', '290000', '8309', '1907', '2/3', 'no', 'average', 'own', 'E2018']
# ['Kamppi', '1h, avok,', 'kt', '26,00', '168000', '6462', '1906', '1/5', 'yes', '', 'own', 'G2013']
# ['Merihaka', '1h, kk, alk, kp...', 'kt', '32,00', '170000', '5313', '1980', '1/8', 'yes', 'average', 'own', 'D2018']
# ['Meilahti', '1h, avok, kph', 'kt', '21,00', '152250', '7250', '1949', '5/8', 'yes', 'good', 'own', 'D2018']
# ['Vallila', '1h, avok, kph', 'kt', '24,60', '146500', '5955', '1928', '4/5', 'no', 'average', 'own', 'E2018']
# ['Taka-töölö', '1h, avok, kph', 'kt', '25,00', '120000', '4800', '1939', '6/6', 'yes', 'average', 'own', 'F2013']
# ['Harju', '1h, alk, k, kph...', 'kt', '46,60', '245000', '5258', '1912', '5/5', 'no', 'average', 'own', 'E2018']
# ['Kallio', '1h+k+kph+sauna', 'kt', '52,50', '250000', '4762', '1932', '6/6', 'yes', 'average', 'own', 'D']
# ['Alppiharju', '1h+kk+alk+wc', 'kt', '21,40', '135000', '6308', '1940', '5/6', 'yes', 'good', 'own', 'E2018']
# ['Taka-töölö', '1h, kk, kph', 'kt', '24,00', '175000', '7292', '1952', '3/7', 'yes', 'average', 'own', 'D2018']
# ['Maunula', '1h, kk, kph, al...', 'kt', '24,50', '120000', '4898', '1962', '6/6', 'yes', 'good', 'rent', 'G2013']
# ['Hietalahti', '1 h + kk', 'kt', '27,00', '220000', '8148', '1961', '5/8', 'yes', 'good', 'own', 'E2007']
# ['Kruununhaka', 'Studio, avok, kph', 'kt', '55,00', '360000', '6545', '1924', '2/5', 'no', 'average', 'own', 'D2007']
# ['Puotila', '1h, kk, kph/wc', 'kt', '25,00', '131000', '5240', '1961', '2/3', 'no', 'good', 'own', 'E2018']
# ['Alppila', '1 h+kk+kph+las....', 'kt', '25,00', '193000', '7720', '1982', '1/3', 'no', 'good', 'own', '']
# ['Etelä-haaga', '1h+kt', 'kt', '26,00', '179000', '6885', '2016', '3/3', 'yes', 'good', 'rent', '']
# ['Ullanlinna', '1h, avok, kph', 'kt', '21,00', '222500', '10595', '1928', '3/4', 'yes', 'good', 'own', 'F2013']
# ['Etelä-haaga', '1h, avok, kph, ...', 'kt', '24,50', '135000', '5510', '1964', '1/3', 'no', 'good', 'own', 'F2018']
# ['Lauttasaari', '1h, kk', 'kt', '30,50', '207000', '6787', '1975', '4/7', 'yes', 'good', 'own', 'F2013']
# ['Ruskeasuo', '1h, avok, kph, et', 'kt', '38,50', '215000', '5584', '1955', '3/3', 'no', 'good', 'rent', 'G2013']
# ['Kallio', '1h + avok + kph', 'kt', '26,90', '166500', '6190', '1927', '4/7', 'yes', 'good', 'own', 'E2018']
# ['Kallio', '1h, kk, kph', 'kt', '27,00', '185500', '6870', '1961', '4/6', 'yes', 'good', 'own', 'F2013']
# ['Taka-töölö', 'huone, avokeitt...', 'kt', '28,00', '238000', '8500', '1938', '6/7', 'yes', 'good', 'own', 'D2007']
# ['Etelä-haaga', '1h, kk, kph, ra...', 'kt', '28,00', '155000', '5536', '1960', '2/2', 'no', 'average', 'own', 'D2018']
# ['Puotila', '1h+kk+kph+p.', 'kt', '33,00', '115000', '3485', '1960', '3/3', 'no', 'good', 'rent', 'D2007']
# ['Oulunkylä', '1 h, kk, alkovi...', 'kt', '32,00', '130000', '4063', '1963', '1/3', 'no', 'average', 'own', 'F2013']
# ['Sörnäinen', '1h, k, kph ja e...', 'kt', '39,00', '208000', '5333', '1927', '4/5', 'yes', 'average', 'own', 'E2018']
# ['Aurinkolahti', '1-2h+avok.+kph+...', 'kt', '42,00', '190000', '4524', '2012', '6/6', 'yes', 'good', 'own', 'B2013']
# ['Alppiharju', '1h+k+kph', 'kt', '36,50', '215000', '5890', '1959', '3/6', 'yes', 'average', 'own', 'D2018']
# ['Etelä-haaga', '1h, k, kph, piha', 'kt', '25,60', '160000', '6250', '1959', '1/3', 'no', 'good', 'own', 'E2018']
# ['Sompasaari', '1h+avok+kph+ter...', 'kt', '31,50', '279500', '8873', '2020', '3/8', 'yes', 'good', 'own', 'C2013']
# ['Vilhonvuori', '1h + avok. + kph', 'kt', '18,20', '131000', '7198', '1938', '5/7', 'yes', 'average', 'own', 'F2013']
# ['Vallila', '1h+avokeitti\x02...', 'kt', '26,00', '185000', '7115', '1929', '1/3', 'no', 'good', 'own', '']
# ['Punavuori', '1h, avok, vh, kph', 'kt', '32,50', '265000', '8154', '1963', '2/4', 'no', 'good', 'own', 'F2013']
# ['Ullanlinna', '1h,alk,k', 'kt', '39,00', '332000', '8513', '1908', '1/3', 'no', 'average', 'own', 'F2013']
# ['Kruununhaka', '1h, avok, kph', 'kt', '30,00', '242000', '8067', '1938', '3/4', 'yes', 'average', 'own', 'E2018']
# ['Punavuori', '1h, k, et, kph', 'kt', '26,00', '190000', '7308', '1927', '2/5', 'yes', 'poor', 'own', 'F2013']
# ['Punavuori', '1h, k, alkovi, kph', 'kt', '36,50', '325000', '8904', '1923', '', 'no', 'good', 'own', 'D2018']
# ['Töölö', '1h, k, kph, vh', 'kt', '38,00', '218000', '5737', '1927', '2/7', 'yes', 'average', 'own', '']
# ['Tapanila', '1h, avok, kph, ...', 'kt', '29,00', '132500', '4569', '1919', '1/3', 'no', 'good', 'own', 'E']
# ['Kamppi', '1h, k, kph', 'kt', '38,50', '322500', '8377', '1927', '3/5', 'yes', 'good', 'own', 'F2013']
# ['Oulunkylä', '1 h, kk, vh, kp...', 'kt', '27,00', '94000', '3481', '1963', '3/3', 'no', 'average', 'rent', 'F2013']
# ['Lauttasaari', '1 h+kk+parv.', 'kt', '29,00', '157000', '5414', '1972', '1/6', 'yes', 'average', 'own', 'E2018']
# ['Etu-töölö', '1h, avok, alkov...', 'kt', '41,00', '355000', '8659', '1927', '2/6', 'yes', 'good', 'own', 'D2007']
# ['Roihuvuori', '1h, kk, kph', 'kt', '22,00', '119220', '5419', '1961', '3/3', 'no', 'average', 'rent', '']
# ['Taka-töölö', '1h+kk', 'kt', '22,00', '146500', '6659', '1939', '1/3', 'no', '', 'own', 'E2013']
# ['Mellunkylä', '1h,k,kh', 'kt', '31,50', '80000', '2540', '1965', '2/2', 'no', 'average', 'own', 'E2018']
# ['Kontula', '1h, kk, kph, la...', 'kt', '38,00', '125000', '3289', '1967', '5/8', 'yes', 'average', 'rent', 'C2018']
# ['Pukinmäki', '1h, avok, alkov...', 'kt', '31,50', '134000', '4254', '1985', '2/5', 'yes', 'good', 'own', '']
# ['Puistola', '1h+avok+kph+vh', 'kt', '34,50', '123000', '3565', '1974', '1/2', 'no', 'good', 'rent', 'C2018']
# ['Taka-töölö', '1h, alkovi, k, ...', 'kt', '41,00', '266000', '6488', '1932', '5/6', 'yes', 'average', 'own', 'E2007']
# ['Lassila', '1h, avok, kph, ...', 'kt', '29,50', '131000', '4441', '1990', '1/3', 'no', 'good', 'own', 'F2013']
# ['3', '', '3', '']
# ['', '3', '']
# []
# ['4', '', '4', '']
# ['', '4', '']
# ['Studio apartment']
# ['Kamppi', '1h+kph', 'kt', '23,00', '175000', '7609', '1936', '3/4', 'yes', 'average', 'own', 'F2018']
# ['Oulunkylä', 'i h, k, kh (Yj ...', 'kt', '33,00', '177441', '5377', '1977', '1/3', 'no', 'good', 'own', 'F2013']
# ['Arabianranta', '1h+k', 'kt', '40,00', '274500', '6863', '2005', '1/4', 'yes', 'good', 'own', 'E2013']
# ['Meilahti', '1h, kk, wc (yj:...', 'kt', '20,00', '118000', '5900', '1945', '5/7', 'yes', 'average', 'own', 'E2013']
# ['Siltamäki', '1 h, kk, kh/wc,...', 'kt', '33,00', '90000', '2727', '1973', '1/3', 'no', 'average', 'own', 'F2013']
# ['Pitäjänmäki', '1h, kk, kph', 'kt', '24,00', '103000', '4292', '1957', '2/3', 'no', 'average', 'rent', 'E2018']
# ['Punavuori', '1 h+kk', 'kt', '20,00', '179000', '8950', '1959', '7/7', 'yes', 'average', 'own', 'F2013']
# ['Meilahti', '1h, kk, kph', 'kt', '21,20', '183000', '8632', '1946', '4/7', 'yes', 'good', 'own', 'D2018']
# ['Sörnäinen', '1 h, keitti\x18...', 'kt', '33,50', '161000', '4806', '1961', '2/8', 'yes', 'average', 'own', 'E2018']
# ['Malmi', '1h, kk', 'kt', '22,30', '109000', '4888', '1965', '3/3', 'no', 'good', 'own', 'E2013']
# ['Savela', '1 huone, keitto...', 'kt', '34,50', '134000', '3884', '1985', '2/2', 'no', 'average', 'own', 'F2013']
# ['Punavuori', '1h, kk,kph', 'kt', '21,10', '177000', '8389', '1910', '-1/4', 'no', 'average', 'own', 'E2007']
# ['Munkkivuori', '1h, kk, kph', 'kt', '23,00', '144744', '6293', '1958', '3/4', 'no', 'average', 'own', 'G2007']
# ['Kamppi', '1h+kk', 'kt', '25,00', '214000', '8560', '1961', '2/6', 'yes', 'good', 'own', 'D2018']
# ['Kalasatama', '1h+kt', 'kt', '31,50', '250264', '7945', '2024', '6/7', 'yes', 'good', 'rent', 'A2018']
# ['Oulunkylä', '1h, kk, kph', 'kt', '34,00', '143000', '4206', '1971', '2/3', 'no', 'good', 'rent', 'D2007']
# ['Kallio', '1h, avok, alkov...', 'kt', '20,00', '144000', '7200', '1932', '2/8', 'yes', 'average', 'own', 'D2018']
# ['Puotila', '1h+kk', 'kt', '24,50', '108000', '4408', '1961', '3/3', 'no', 'average', 'own', 'F2018']
# ['Kallio', '1 h, kk, kph', 'kt', '25,00', '165000', '6600', '1913', '3/6', 'no', 'good', 'own', 'E2007']
# ['Kallio', '1h, avok, kph, ...', 'kt', '31,00', '205000', '6613', '1907', '', 'yes', 'good', 'own', 'F2013']
# ['Kallio', '1h,avok,kh (Yj ...', 'kt', '31,70', '185000', '5836', '1929', '7/7', 'yes', 'average', 'own', 'F2018']
# ['Kruununhaka', '1h, kk, kh', 'kt', '27,40', '255000', '9307', '1927', '4/4', 'yes', 'average', 'own', 'C2018']
# ['Munkkivuori', '1h, k, kph, alk...', 'kt', '31,00', '173000', '5581', '1957', '9/10', 'yes', 'good', 'rent', 'E2013']
# ['Hietalahti', '1h', 'kt', '23,50', '164000', '6979', '1927', '7/7', 'no', 'average', 'own', '']
# ['Kamppi', '1h,kph, wc, kei...', 'kt', '28,00', '206000', '7357', '1911', '2/5', 'yes', 'poor', 'own', '']
# ['Lauttasaari', '1h+k', 'kt', '36,00', '214000', '5944', '1956', '3/5', 'yes', 'good', 'own', 'G2013']
# ['Herttoniemi', '1h, kk, ranskal...', 'kt', '27,50', '142600', '5185', '1956', '5/7', 'yes', 'poor', 'rent', 'F2013']
# ['Mellunkylä', '1 h + kt', 'kt', '31,00', '138000', '4452', '2020', '4/5', 'yes', 'good', 'rent', 'B2018']
# ['Haaga', '1 h, kk, kph', 'kt', '27,80', '120000', '4317', '1954', '1/4', 'no', 'average', 'own', 'D2018']
# ['Pihlajamäki', '1h+k+alk.+kph+p', 'kt', '34,50', '130000', '3768', '1964', '5/8', 'yes', 'good', 'rent', 'G2013']
# ['Hakaniemi', '1h+k+kph+WC', 'kt', '22,50', '175000', '7778', '1927', '2/6', 'yes', 'poor', 'own', 'E2018']
# ['Lassila', '1h, alkovi, kk,...', 'kt', '33,00', '132000', '4000', '1978', '7/7', 'yes', 'average', 'rent', 'C2018']
# ['Laajasalo', '1 h, kk, kph, v...', 'kt', '33,00', '133000', '4030', '1973', '2/3', 'no', 'good', 'own', 'E2013']
# ['Patola', '1h+kk', 'kt', '34,30', '69000', '2012', '1975', '1/3', 'no', 'average', 'rent', 'D2018']
# ['Pukinmäki', '1h, kk, kph, wc...', 'kt', '30,00', '127000', '4233', '1982', '1/5', 'yes', 'good', 'own', 'F2013']
# ['Punavuori', '1h+k', 'kt', '44,00', '318000', '7227', '1910', '1/4', 'no', 'average', 'own', '']
# ['Taka-töölö', '1h, wc', 'kt', '23,00', '160000', '6957', '1914', '4/5', 'no', 'poor', 'own', 'D2018']
# ['Kallio', '1 k, k, kph, er...', 'kt', '36,00', '205000', '5694', '1925', '4/5', 'no', 'average', 'own', 'D2007']
# ['Roihuvuori', '1h, kk, kph/wc', 'kt', '27,50', '115000', '4182', '1958', '2/3', 'no', 'average', 'rent', '']
# ['Etu-töölö', '1h, k, kph', 'kt', '29,50', '205000', '6949', '1934', '4/7', 'yes', 'average', 'own', 'D2007']
# ['Etu-töölö', '1h, avokeitti&#...', 'kt', '39,00', '280000', '7179', '1912', '5/7', 'yes', 'average', 'own', 'G2013']
# ['Maunula', '1k, kk', 'kt', '26,00', '110000', '4231', '1962', '4/4', 'yes', 'good', 'rent', 'E2007']
# ['Käpylä', '1h+kk+khwc+p', 'kt', '29,50', '173000', '5864', '1952', '1/4', 'no', 'good', 'rent', 'G2013']
# ['Kruununhaka', '1h, k, kph', 'kt', '39,30', '300000', '7634', '1927', '3/4', 'yes', 'average', 'own', 'D']
# ['Kallio', '1h, avokeitti&#...</td>\n\t\t\t\t\t\t\t<td class="houseType">kt</td>\n\t\t\t\t\t\t\t<td class="cellAlignRight">40,00</td>\n\t\t\t\t\t\t\t<td class="cellAlignRight">210000</td>\n\t\t\t\t\t\t\t<td class="cellAlignRight">5250</td>\n\t\t\t\t\t\t\t<td class="cellAlignRight">1928</td>\n\t\t\t\t\t\t\t<td>3/6</td>\n\t\t\t\t\t\t\t<td>yes</td>\n\t\t\t\t\t\t\t<td>average</td>\n\t\t\t\t\t\t\t<td>own</td>\n\t\t\t\t\t\t\t<td>F<sub>2007</sub></td>\n\t\t\t\t\t\t</tr>\n\t\t\t\t\t\t<tr>\n\t\t\t\t\t\t\t<td class="neighborhood">It&#228;-pasila</td>\n\t\t\t\t\t\t\t<td>1h, kk, kph</td>\n\t\t\t\t\t\t\t<td class="houseType">kt</td>\n\t\t\t\t\t\t\t<td class="cellAlignRight">31,50</td>\n\t\t\t\t\t\t\t<td class="cellAlignRight">158000</td>\n\t\t\t\t\t\t\t<td class="cellAlignRight">5016</td>\n\t\t\t\t\t\t\t<td class="cellAlignRight">1976</td>\n\t\t\t\t\t\t\t<td>11/13</td>\n\t\t\t\t\t\t\t<td>yes</td>\n\t\t\t\t\t\t\t<td>average</td>\n\t\t\t\t\t\t\t<td>rent</td>\n\t\t\t\t\t\t\t<td>E<sub>2018</sub></td>\n\t\t\t\t\t\t</tr>\n\t\t\t\t\t\t<tr>\n\t\t\t\t\t\t\t<td class="neighborhood">Malmi</td>\n\t\t\t\t\t\t\t<td>1h, kk, kph, sa...</td>\n\t\t\t\t\t\t\t<td class="houseType">kt</td>\n\t\t\t\t\t\t\t<td class="cellAlignRight">33,00</td>\n\t\t\t\t\t\t\t<td class="cellAlignRight">135000</td>\n\t\t\t\t\t\t\t<td class="cellAlignRight">4091</td>\n\t\t\t\t\t\t\t<td class="cellAlignRight">1986</td>\n\t\t\t\t\t\t\t<td>2/4</td>\n\t\t\t\t\t\t\t<td>no</td>\n\t\t\t\t\t\t\t<td>good</td>\n\t\t\t\t\t\t\t<td>own</td>\n\t\t\t\t\t\t\t<td>F<sub>2013</sub></td>\n\t\t\t\t\t\t</tr>\n\t\t\t\t\t\t<tr>\n\t\t\t\t\t\t\t<td class="neighborhood">Hietalahti</td>\n\t\t\t\t\t\t\t<td>1h,kt,kph,parveke</td>\n\t\t\t\t\t\t\t<td class="houseType">kt</td>\n\t\t\t\t\t\t\t<td class="cellAlignRight">33,00</td>\n\t\t\t\t\t\t\t<td class="cellAlignRight">329000</td>\n\t\t\t\t\t\t\t<td class="cellAlignRight">9970</td>\n\t\t\t\t\t\t\t<td class="cellAlignRight">2024</td>\n\t\t\t\t\t\t\t<td>3/8</td>\n\t\t\t\t\t\t\t<td>yes</td>\n\t\t\t\t\t\t\t<td>&#160;</td>\n\t\t\t\t\t\t\t<td>own</td>\n\t\t\t\t\t\t\t<td>C<sub>2018</sub></td>\n\t\t\t\t\t\t</tr>\n\t\t\t\t\t\t<tr>\n\t\t\t\t\t\t\t<td class="neighborhood">Hietalahti</td>\n\t\t\t\t\t\t\t<td>1h,kt,kph,parveke</td>\n\t\t\t\t\t\t\t<td class="houseType">kt</td>\n\t\t\t\t\t\t\t<td class="cellAlignRight">25,00</td>\n\t\t\t\t\t\t\t<td class="cellAlignRight">269000</td>\n\t\t\t\t\t\t\t<td class="cellAlignRight">10760</td>\n\t\t\t\t\t\t\t<td class="cellAlignRight">2024</td>\n\t\t\t\t\t\t\t<td>4/8</td>\n\t\t\t\t\t\t\t<td>yes</td>\n\t\t\t\t\t\t\t<td>&#160;</td>\n\t\t\t\t\t\t\t<td>own</td>\n\t\t\t\t\t\t\t<td>C<sub>2018</sub></td>\n\t\t\t\t\t\t</tr>\n\t\t\t\t\t\t<tr>\n\t\t\t\t\t\t\t<td class="neighborhood">Vuosaari</td>\n\t\t\t\t\t\t\t<td>1h, kk, kph, pa...</td>\n\t\t\t\t\t\t\t<td class="houseType">kt</td>\n\t\t\t\t\t\t\t<td class="cellAlignRight">31,00</td>\n\t\t\t\t\t\t\t<td class="cellAlignRight">115000</td>\n\t\t\t\t\t\t\t<td class="cellAlignRight">3710</td>\n\t\t\t\t\t\t\t<td class="cellAlignRight">1971</td>\n\t\t\t\t\t\t\t<td>6/6</td>\n\t\t\t\t\t\t\t<td>yes</td>\n\t\t\t\t\t\t\t<td>average</td>\n\t\t\t\t\t\t\t<td>own</td>\n\t\t\t\t\t\t\t<td>G<sub>2013</sub></td>\n\t\t\t\t\t\t</tr>\n\t\t\t\t\t\t<tr>\n\t\t\t\t\t\t\t<td class="neighborhood">Puotila</td>\n\t\t\t\t\t\t\t<td>1 h+kk+kph+p</td>\n\t\t\t\t\t\t\t<td class="houseType">kt</td>\n\t\t\t\t\t\t\t<td class="cellAlignRight">24,50</td>\n\t\t\t\t\t\t\t<td class="cellAlignRight">130000</td>\n\t\t\t\t\t\t\t<td class="cellAlignRight">5306</td>\n\t\t\t\t\t\t\t<td class="cellAlignRight">1970</td>\n\t\t\t\t\t\t\t<td>2/3</td>\n\t\t\t\t\t\t\t<td>no</td>\n\t\t\t\t\t\t\t<td>good</td>\n\t\t\t\t\t\t\t<td>own</td>\n\t\t\t\t\t\t\t<td>F<sub>2018</sub></td>\n\t\t\t\t\t\t</tr>\n\t\t\t\t\t\t<tr>\n\t\t\t\t\t\t\t<td class="neighborhood">Lassila</td>\n\t\t\t\t\t\t\t<td>1h, avok. kph, ...</td>\n\t\t\t\t\t\t\t<td class="houseType">kt</td>\n\t\t\t\t\t\t\t<td class="cellAlignRight">26,00</td>\n\t\t\t\t\t\t\t<td class="cellAlignRight">114000</td ...
# []
# ['5', '', '5', '']
# ['', '5', '']
# ['Studio apartment']
# ['Kallio', '1h+kk+kph', 'kt', '30,00', '96000', '3200', '1927', '5/6', 'yes', 'average', 'own', 'E2018']
# ['Alppila', '1h,kk, vh ja kph', 'kt', '26,00', '152000', '5846', '1962', '3/10', 'yes', 'average', 'own', 'C2018']
# ['Malmi', '1h, avok, kph, ...', 'kt', '28,00', '119000', '4250', '2020', '3/4', 'yes', 'good', 'rent', 'B2018']
# ['Munkkivuori', '1h, kk, kph, et...', 'kt', '28,50', '189000', '6632', '1959', '5/6', 'yes', 'good', 'own', 'D2018']
# ['Munkkiniemi', '1h, kk, kph, pa...', 'kt', '33,00', '195000', '5909', '1954', '1/4', 'no', 'poor', 'own', 'F2013']
# ['Kallio', '1h+k+kph+wc', 'kt', '37,50', '205996', '5493', '1927', '6/7', 'yes', 'average', 'own', 'F2013']
# ['Alppila', '1h, k, kph', 'kt', '27,00', '160000', '5926', '1928', '3/4', 'no', 'average', 'own', 'F2018']
# ['Yliskylä', '1h+kk', 'kt', '29,00', '131040', '4519', '1971', '2/5', 'yes', 'average', 'own', 'E2018']
# ['Lauttasaari', '1h+kk+alkovi+kph', 'kt', '30,00', '210000', '7000', '1954', '1/4', 'yes', 'good', 'own', 'F2018']
# ['Kallio', '1h + avokeitti&...', 'kt', '30,50', '198500', '6508', '1929', '3/6', 'yes', 'average', 'own', 'E2013']
# ['Oulunkylä', '1 h, kt, kh, p ...', 'kt', '39,00', '136000', '3487', '1983', '2/2', 'no', 'average', 'own', 'D2018']
# ['Alppila', '1h, avokeitti&#...', 'kt', '42,50', '310000', '7294', '1920', '2/7', 'yes', 'average', 'own', 'F2013']
# ['Töölö', 'huone, kk, kph', 'kt', '19,00', '164000', '8632', '1933', '2/6', 'yes', 'average', 'own', 'E2018']
# ['Ullanlinna', '1h, kt, kph', 'kt', '25,00', '208000', '8320', '1935', '5/5', 'yes', 'average', 'own', 'E2013']
# ['Pihlajisto', '1h+kt', 'kt', '30,00', '170000', '5667', '2023', '', 'yes', 'good', 'rent', '']
# ['Pitäjänmäki', '1h+kk', 'kt', '30,40', '89000', '2928', '1964', '1/3', 'no', 'average', 'rent', 'E2018']
# ['Kontula', '1h, kk, kph', 'kt', '31,00', '122500', '3952', '1970', '5/8', 'yes', 'good', 'own', 'G2013']
# ['Pasila', '1h, avok, kph, ...', 'kt', '30,00', '240000', '8000', '2020', '2/12', 'yes', 'good', 'own', 'C2013']
# ['Munkkivuori', '1h+kk+kph', 'kt', '31,50', '174000', '5524', '1958', '2/4', 'no', 'good', 'own', 'D2007']
# ['Punavuori', '1h, avok, kph j...', 'kt', '38,00', '333000', '8763', '1875', '3/5', 'no', 'good', 'own', 'E2018']
# ['Etu-töölö', '1h, avok, kph', 'kt', '24,20', '215000', '8884', '1926', '2/6', 'yes', 'average', 'own', 'F2013']
# ['Kamppi', '1h, kk, kph, pa...', 'kt', '26,00', '185000', '7115', '1981', '2/7', 'yes', 'average', 'own', 'E2013']
# ['Maunula', '1h, kk, kph', 'kt', '24,10', '95000', '3942', '1952', '1/4', 'no', '', 'rent', 'D2018']
# ['Lauttasaari', '1h, k, kph, ete...', 'kt', '31,50', '220000', '6984', '1966', '3/5', 'yes', 'good', 'own', 'F2013']
# ['Suurmetsä', '1h, k, kph', 'kt', '33,50', '68000', '2030', '1973', '1/3', 'no', 'poor', 'rent', 'F2013']
# ['Alppiharju', '1h+k+et+wc+sh', 'kt', '36,60', '260000', '7104', '1912', '4/6', 'yes', 'good', 'own', 'E2007']
# ['Kallio', '1h+alkovi+k+kph', 'kt', '45,30', '246000', '5430', '1925', '3/6', 'yes', 'good', 'own', 'D2018']
# ['Lassila', '1h, kk, kph, s,...', 'kt', '35,00', '130000', '3714', '1984', '2/5', 'yes', 'average', 'own', 'E2018']
# ['Kallio', '1h,k, alkovi', 'kt', '41,00', '214000', '5220', '1939', '6/6', 'yes', 'average', 'own', 'F2013']
# ['Torkkelinmäki', '1h, k, kph', 'kt', '44,70', '255000', '5705', '1928', '2/4', 'no', 'poor', 'own', 'E2018']
# ['Kallio', '1h, avok, alkov...', 'kt', '26,00', '195000', '7500', '1929', '4/4', 'no', 'average', 'own', 'D2018']
# ['Pitäjänmäki', '1h, k, kph, p', 'kt', '32,50', '79290', '2440', '1974', '1/5', 'yes', 'average', 'own', 'F2013']
# ['Pohjois-haaga', '1h+kk', 'kt', '27,00', '115000', '4259', '1954', '1/3', 'no', 'average', 'own', 'F2013']
# ['Puotila', '1h, kk, vaatehu...', 'kt', '28,30', '92000', '3251', '1961', '2/3', 'no', 'poor', 'rent', 'E2007']
# ['Katajanokka', '1h, k', 'kt', '41,00', '220000', '5366', '1981', '3/5', 'yes', 'good', 'rent', 'D2018']
# ['Kallio', '1h,kk', 'kt', '18,60', '120000', '6452', '1931', '4/7', 'yes', 'poor', 'own', 'E2007']
# ['Sörnäinen', '1h ja kk', 'kt', '25,00', '130000', '5200', '1937', '4/8', 'yes', 'average', 'own', 'E2018']
# ['Etelä-haaga', '1h, kk, kh, parv', 'kt', '30,00', '175000', '5833', '1961', '1/3', 'no', 'good', 'own', 'F2007']
# ['Etelä-haaga', '1h,kk, kph, alk...', 'kt', '30,50', '166000', '5443', '1961', '1/3', 'no', 'good', 'own', 'F2007']
# ['Itä-pasila', '1h, kk, kph, la...', 'kt', '35,50', '111000', '3127', '1975', '1/5', 'yes', 'poor', 'rent', 'D2018']
# ['Arabianranta', '1-2h, k', 'kt', '47,50', '296000', '6232', '2015', '6/9', 'yes', 'good', 'own', 'B2018']
# ['Meilahti', '1h, kk, kph', 'kt', '24,00', '185000', '7708', '1946', '4/7', 'yes', 'good', 'own', 'E2013']
# ['Malminkartano', '1 h, k, kph, pi...', 'kt', '31,50', '103550', '3287', '1986', '1/4', 'no', 'average', 'rent', 'E2018']
# ['Etelä-haaga', '1h, alkovi, kk,...', 'kt', '32,00', '148000', '4625', '1960', '1/2', 'no', 'poor', 'own', 'C2018']
# ['Taka-töölö', '1h,k, alk ja kph', 'kt', '40,00', '261000', '6525', '1932', '2/5', 'yes', 'average', 'own', 'E2007']
# ['Pajamäki', '1h, kk, kph', 'kt', '22,80', '92500', '4057', '1960', '2/4', 'no', 'good', 'rent', 'F2018']
# ['Taka-töölö', '1 h + kk + wc (...', 'kt', '21,00', '156000', '7429', '1938', '2/5', 'yes', 'good', 'own', 'F2007']
# ['Munkkiniemi', '1h, avok., kph, p', 'kt', '22,00', '170000', '7727', '1959', '2/4', 'yes', 'good', 'own', 'E2007']
# ['Kallio', '1h+kh+alkovi', 'kt', '30,00', '179000', '5967', '1937', '3/7', 'yes', 'average', 'own', 'G2013']
# ['Itäkeskus', '1h, kk, kh, alk...', 'kt', '36,50', '120500', '3301', '1979', '3/4', 'yes', 'average', 'rent', 'D2018']
# ['Malminkartano', '1h, kk, s, kph,...', 'kt', '37,00', '105000', '2838', '1989', '2/3', 'no', 'average', 'rent', 'F2013']
# ['Taka-töölö', '1h, k, kph', 'kt', '38,00', '252394', '6642', '1927', '3/7', 'yes', 'good', 'own', 'D2007']
# ['5', '', '5', '']
# ['', '5', '']
# []
# ['6', '', '6', '']
# ['', '6', '']
# ['Studio apartment']
# ['Oulunkylä', '1h, kk, alkovi, vh', 'kt', '30,00', '175000', '5833', '1964', '2/3', 'no', 'good', 'own', 'F2013']
# ['Punavuori', '1 h, kk, lasit....', 'kt', '26,00', '225000', '8654', '1961', '4/5', 'yes', 'good', 'own', 'E2013']
# ['Etu-töölö', '1 h, k, makuuso...', 'kt', '48,00', '379000', '7896', '1928', '3/6', 'yes', 'good', 'own', 'F2013']
# ['Munkkivuori', '1h+kk+kph', 'kt', '26,00', '153000', '5885', '1960', '3/4', 'no', 'good', 'rent', 'D2018']
# ['Etelä-haaga', '1h, avok, kph', 'kt', '20,00', '126000', '6300', '1958', '2/3', 'no', 'good', 'own', 'D2018']
# ['Etelä-haaga', '1h, kk, kph, vh', 'kt', '28,00', '135000', '4821', '1964', '4/4', 'yes', 'average', 'rent', 'G2013']
# ['Punavuori', '1h+kk+kph', 'kt', '32,00', '255000', '7969', '1962', '4/5', 'yes', 'average', 'own', 'F2013']
# ['Puotila', '1h+avok+s+p', 'kt', '35,50', '180000', '5070', '2006', '3/5', 'yes', 'good', 'own', 'D']
# ['Kruununhaka', '1h, kk, kph', 'kt', '27,00', '240000', '8889', '1927', '4/6', 'yes', 'good', 'own', 'E2018']
# ['Punavuori', '1h+k', 'kt', '29,00', '275000', '9483', '1907', '', 'no', 'average', 'own', 'G2013']
# ['Kallio', '1h, avok, suihk...', 'kt', '34,00', '123000', '3618', '1928', '1/7', 'yes', 'average', 'own', 'D2018']
# ['Konala', '1h, avokeitti&#...', 'kt', '37,00', '150000', '4054', '1982', '2/3', 'no', 'good', 'own', 'E2013']
# ['Hakaniemi', '1h, avok, kph', 'kt', '28,50', '220000', '7719', '1961', '3/7', 'yes', 'good', 'own', 'E2018']
# ['Kallio', '1h+kk+kh', 'kt', '27,00', '193000', '7148', '1961', '3/6', 'yes', 'average', 'own', 'F2013']
# ['Vallila', '1h+k+alk', 'kt', '37,00', '245000', '6622', '1929', '3/4', 'no', 'good', 'own', '']
# ['Alppila', '1h, avok ja kph', 'kt', '38,50', '245000', '6364', '1912', '1/4', 'no', 'good', 'own', 'F2007']
# ['Mellunmäki', '1h, kk, vh, par...', 'kt', '34,00', '79000', '2324', '1973', '3/4', 'yes', 'average', 'own', 'F2007']
# ['Vuosaari', '1h+kk+parveke', 'kt', '37,00', '140000', '3784', '1966', '5/8', 'yes', 'good', 'own', 'E2018']
# ['Pohjois-haaga', '1h, kk, kph, ra...', 'kt', '23,50', '148000', '6298', '1954', '1/4', 'no', 'good', 'own', 'E2018']
# ['Tapaninvainio', '1 h, avok, alko...', 'kt', '34,50', '128000', '3710', '1982', '2/3', 'no', 'average', 'own', 'C2018']
# ['Kallio', '1h+k+alk+kph', 'kt', '41,00', '210000', '5122', '1939', '4/6', 'yes', 'average', 'own', 'F2013']
# ['Lauttasaari', '1h+kk+vh+kph+la...', 'kt', '25,50', '156000', '6118', '1961', '2/5', 'yes', 'poor', 'own', 'C2018']
# ['Puotinharju', '1 h, kk, kph (Y...', 'kt', '32,00', '105000', '3281', '1964', '7/7', 'yes', 'average', 'rent', 'D2018']
# ['Kallio', '1h, kk, kph, vh', 'kt', '31,30', '218000', '6965', '1925', '6/6', 'yes', 'average', 'own', 'D2018']
# ['Harju', '1h+k+alk+parvi+kph', 'kt', '48,40', '340000', '7025', '1911', '3/6', 'yes', 'good', 'own', 'G2013']
# ['Kallio', '1h,avok,wc/suihku', 'kt', '20,30', '151000', '7438', '1907', '4/5', 'no', 'poor', 'own', 'E2013']
# ['Pajamäki', '1 h, kk, kph (Y...', 'kt', '24,00', '118000', '4917', '1958', '2/4', 'no', 'average', 'own', 'D2018']
# ['Pihlajamäki', '1 h, kk, alkovi...', 'kt', '25,00', '122566', '4903', '1969', '2/4', 'yes', 'good', 'own', 'E2018']
# ['Tapulikaupunki', '1h+kk+kph', 'kt', '29,50', '70000', '2373', '1976', '3/6', 'yes', 'good', 'rent', 'F2013']
# ['Patola', '1h, kk, kph', 'kt', '34,00', '105000', '3088', '1971', '2/3', 'no', 'poor', 'rent', 'D2007']
# ['Lauttasaari', '1h, avok, kph', 'kt', '29,50', '250000', '8475', '1954', '3/4', 'no', 'good', 'own', 'D2018']
# ['Pukinmäki', '1h, kk, psh, pa...', 'kt', '30,00', '116000', '3867', '1986', '3/4', 'no', 'average', 'own', 'D2018']
# ['Pihlajamäki', '1h, kk, kph', 'kt', '24,50', '58000', '2367', '1963', '1/4', 'yes', 'poor', 'rent', 'F2013']
# ['Lehtisaari', '1h+kk+kph+vh+pa...', 'kt', '29,90', '136000', '4548', '1967', '2/4', 'yes', 'average', 'rent', '']
# ['Kamppi', '1h, alkovi, kk,...', 'kt', '30,00', '234000', '7800', '1932', '2/5', 'yes', 'poor', 'own', 'E2018']
# ['Lauttasaari', '1h, kk, kph, pa...', 'kt', '33,00', '210000', '6364', '1976', '1/6', 'yes', 'good', 'own', 'F2013']
# ['Ala-tikkurila', '1h, k, kph,s, v...', 'rt', '36,50', '135000', '3699', '1989', '1/1', 'no', 'average', 'own', 'E2007']
# ['Munkkivuori', '1h, alkovi, kk,...', 'kt', '31,00', '162000', '5226', '1957', '10/10', 'yes', 'good', 'rent', 'E2013']
# ['Herttoniemi', '1 h, kk, kph, r...', 'kt', '31,10', '120000', '3859', '1953', '4/4', 'no', 'poor', 'rent', 'E2007']
# ['Vallila', '1h, avok, kph', 'kt', '49,50', '292500', '5909', '1929', '3/4', 'yes', 'good', 'own', 'E2018']
# ['Taka-töölö', '1 h,kk,kph', 'kt', '21,00', '159000', '7571', '1938', '2/6', 'yes', 'average', 'own', 'F2018']
# ['Kallio', '1h+kk', 'kt', '31,00', '215000', '6935', '1962', '7/8', 'yes', 'good', 'own', 'F2013']
# ['Siltamäki', '1h+avok+kh+rans...', 'kt', '35,00', '150000', '4286', '2017', '4/4', 'yes', 'good', 'rent', 'C2013']
# ['Ullanlinna', '1 h + kk (yj:n ...', 'kt', '36,00', '215000', '5972', '1961', '1/8', 'yes', 'average', 'own', 'F2013']
# ['Konala', '1h+alkovi+k+kph', 'kt', '31,00', '124000', '4000', '1963', '1/5', 'yes', 'good', 'own', 'D2018']
# ['Kannelmäki', '1 h, kk, kph, p...', 'kt', '34,00', '80500', '2368', '1980', '3/5', 'no', 'poor', 'rent', 'D2007']
# ['Vuosaari', '1 h, k, las. pa...', 'kt', '33,50', '114000', '3403', '1965', '4/4', 'yes', 'good', 'own', 'E2007']
# ['Ruskeasuo', '1h, kk, kph, pa...', 'kt', '28,00', '155000', '5536', '1955', '3/4', 'no', 'poor', 'own', 'E2018']
# ['Pohjois-haaga', '1h, k, kph', 'kt', '33,00', '165000', '5000', '1952', '1/7', 'yes', 'average', 'own', 'E2018']
# ['Kontula', '1h, kk, kph', 'kt', '31,00', '107000', '3452', '1970', '7/8', 'yes', 'average', 'own', 'G2013']
# ['Vuosaari', '1 h+k+kph+lasit...', 'kt', '32,70', '95000', '2905', '1964', '2/3', 'no', 'good', 'own', 'F2007']
# ['Kamppi', '1h, kk', 'kt', '13,70', '127100', '9277', '1926', '3/3', 'no', 'good', 'own', 'F2018']
# ['6', '', '6', '']
# ['', '6', '']
# []
# ['7', '', '7', '']
# ['', '7', '']
# ['Studio apartment']
# ['Vuosaari', '1h, kk, kph, la...', 'kt', '32,00', '132000', '4125', '1971', '4/6', 'yes', 'good', 'own', 'G2013']
# ['Alppila', '1-2h, k, kph', 'kt', '34,00', '234000', '6882', '1929', '3/4', 'no', 'good', 'own', 'D2007']
# ['Munkkiniemi', '1h, kk,kph, par...', 'kt', '30,00', '180000', '6000', '1954', '2/4', 'yes', 'average', 'own', 'E2007']
# ['Kurkimäki', '1h, kk, kph, s,...', 'kt', '41,00', '93000', '2268', '1983', '1/3', 'no', 'average', 'rent', 'E2018']
# ['Kallio', '1h, kk, kph, la...', 'kt', '28,50', '215000', '7544', '1968', '5/6', 'yes', 'good', 'own', 'D2007']
# ['Torkkelinmäki', '1h, avokeitti&#...', 'kt', '27,50', '180000', '6545', '1927', '1/5', 'no', 'average', 'own', 'D2018']
# ['Kallio', '1h', 'kt', '29,30', '162000', '5529', '1927', '5/8', 'yes', 'average', 'own', 'D2018']
# ['Torkkelinmäki', '1h, kph', 'kt', '29,40', '212000', '7211', '1928', '3/8', 'yes', 'good', 'own', 'D2013']
# ['Kruununhaka', '1h, avokeitti&#...</td>\n\t\t\t\t\t\t\t<td class="houseType">kt</td>\n\t\t\t\t\t\t\t<td class="cellAlignRight">29,50</td>\n\t\t\t\t\t\t\t<td class="cellAlignRight">257000</td>\n\t\t\t\t\t\t\t<td class="cellAlignRight">8712</td>\n\t\t\t\t\t\t\t<td class="cellAlignRight">1954</td>\n\t\t\t\t\t\t\t<td>3/8</td>\n\t\t\t\t\t\t\t<td>yes</td>\n\t\t\t\t\t\t\t<td>average</td>\n\t\t\t\t\t\t\t<td>own</td>\n\t\t\t\t\t\t\t<td>E<sub>2013</sub></td>\n\t\t\t\t\t\t</tr>\n\t\t\t\t\t\t<tr>\n\t\t\t\t\t\t\t<td class="neighborhood">Kamppi</td>\n\t\t\t\t\t\t\t<td>1h, k, kph</td>\n\t\t\t\t\t\t\t<td class="houseType">kt</td>\n\t\t\t\t\t\t\t<td class="cellAlignRight">42,00</td>\n\t\t\t\t\t\t\t<td class="cellAlignRight">300000</td>\n\t\t\t\t\t\t\t<td class="cellAlignRight">7143</td>\n\t\t\t\t\t\t\t<td class="cellAlignRight">1902</td>\n\t\t\t\t\t\t\t<td>3/5</td>\n\t\t\t\t\t\t\t<td>no</td>\n\t\t\t\t\t\t\t<td>average</td>\n\t\t\t\t\t\t\t<td>own</td>\n\t\t\t\t\t\t\t<td>E<sub>2018</sub></td>\n\t\t\t\t\t\t</tr>\n\t\t\t\t\t\t<tr>\n\t\t\t\t\t\t\t<td class="neighborhood">Lauttasaari</td>\n\t\t\t\t\t\t\t<td>1h,kk</td>\n\t\t\t\t\t\t\t<td class="houseType">kt</td>\n\t\t\t\t\t\t\t<td class="cellAlignRight">24,00</td>\n\t\t\t\t\t\t\t<td class="cellAlignRight">144000</td>\n\t\t\t\t\t\t\t<td class="cellAlignRight">6000</td>\n\t\t\t\t\t\t\t<td class="cellAlignRight">1938</td>\n\t\t\t\t\t\t\t<td>2/7</td>\n\t\t\t\t\t\t\t<td>yes</td>\n\t\t\t\t\t\t\t<td>average</td>\n\t\t\t\t\t\t\t<td>own</td>\n\t\t\t\t\t\t\t<td>F<sub>2013</sub></td>\n\t\t\t\t\t\t</tr>\n\t\t\t\t\t\t<tr>\n\t\t\t\t\t\t\t<td class="neighborhood">Alppila</td>\n\t\t\t\t\t\t\t<td>1h+kk+kph</td>\n\t\t\t\t\t\t\t<td class="houseType">kt</td>\n\t\t\t\t\t\t\t<td class="cellAlignRight">24,00</td>\n\t\t\t\t\t\t\t<td class="cellAlignRight">173000</td>\n\t\t\t\t\t\t\t<td class="cellAlignRight">7208</td>\n\t\t\t\t\t\t\t<td class="cellAlignRight">1947</td>\n\t\t\t\t\t\t\t<td>3/7</td>\n\t\t\t\t\t\t\t<td>yes</td>\n\t\t\t\t\t\t\t<td>good</td>\n\t\t\t\t\t\t\t<td>own</td>\n\t\t\t\t\t\t\t<td>E<sub>2018</sub></td>\n\t\t\t\t\t\t</tr>\n\t\t\t\t\t\t<tr>\n\t\t\t\t\t\t\t<td class="neighborhood">Puotinharju</td>\n\t\t\t\t\t\t\t<td>1h, kk, kph</td>\n\t\t\t\t\t\t\t<td class="houseType">kt</td>\n\t\t\t\t\t\t\t<td class="cellAlignRight">25,50</td>\n\t\t\t\t\t\t\t<td class="cellAlignRight">74000</td>\n\t\t\t\t\t\t\t<td class="cellAlignRight">2902</td>\n\t\t\t\t\t\t\t<td class="cellAlignRight">1964</td>\n\t\t\t\t\t\t\t<td>3/4</td>\n\t\t\t\t\t\t\t<td>no</td>\n\t\t\t\t\t\t\t<td>poor</td>\n\t\t\t\t\t\t\t<td>rent</td>\n\t\t\t\t\t\t\t<td></td>\n\t\t\t\t\t\t</tr>\n\t\t\t\t\t\t<tr>\n\t\t\t\t\t\t\t<td class="neighborhood">Lauttasaari</td>\n\t\t\t\t\t\t\t<td>1 h, kk, kph,  s</td>\n\t\t\t\t\t\t\t<td class="houseType">kt</td>\n\t\t\t\t\t\t\t<td class="cellAlignRight">33,00</td>\n\t\t\t\t\t\t\t<td class="cellAlignRight">190000</td>\n\t\t\t\t\t\t\t<td class="cellAlignRight">5758</td>\n\t\t\t\t\t\t\t<td class="cellAlignRight">1984</td>\n\t\t\t\t\t\t\t<td>3/3</td>\n\t\t\t\t\t\t\t<td>no</td>\n\t\t\t\t\t\t\t<td>good</td>\n\t\t\t\t\t\t\t<td>own</td>\n\t\t\t\t\t\t\t<td></td>\n\t\t\t\t\t\t</tr>\n\t\t\t\t\t\t<tr>\n\t\t\t\t\t\t\t<td class="neighborhood">Vallila</td>\n\t\t\t\t\t\t\t<td>1h+k+kph</td>\n\t\t\t\t\t\t\t<td class="houseType">kt</td>\n\t\t\t\t\t\t\t<td class="cellAlignRight">34,00</td>\n\t\t\t\t\t\t\t<td class="cellAlignRight">206000</td>\n\t\t\t\t\t\t\t<td class="cellAlignRight">6059</td>\n\t\t\t\t\t\t\t<td class="cellAlignRight">1922</td>\n\t\t\t\t\t\t\t<td>1/2</td>\n\t\t\t\t\t\t\t<td>no</td>\n\t\t\t\t\t\t\t<td>average</td>\n\t\t\t\t\t\t\t<td>rent</td>\n\t\t\t\t\t\t\t<td>D<sub>2018</sub></td>\n\t\t\t\t\t\t</tr>\n\t\t\t\t\t\t<tr>\n\t\t\t\t\t\t\t<td class="neighborhood">Lauttasaari</td>\n\t\t\t\t\t\t\t<td>1h , alkovi,  k...</td>\n\t\t\t\t\t\t\t<td class="houseType">kt</td>\n\t\t\t\t\t\t\t<td class="cellAlignRight">27,20</td>\n\t\t\t\t\t\t\t<td class="cellAlignRight">210000</td>\n\t\t\t\t\t\t\t<td class="cellAlignRight">7721</td>\n\t\t\t\t\t ...
# []
# ['8', '', '8', '']
# ['', '8', '']
# ['Studio apartment']
# ['Kallio', '1h, avokeitti&#...', 'kt', '20,00', '180000', '9000', '1928', '2/4', 'no', 'average', 'own', 'F2007']
# ['Konala', '1h, kk, kph ja ...', 'kt', '21,00', '72000', '3429', '1963', '1/4', 'no', 'poor', 'own', 'F2013']
# ['Itä-pasila', '1h, k, alkovi, ...', 'kt', '38,00', '172000', '4526', '1974', '5/8', 'yes', 'average', 'rent', 'G2013']
# ['Katajanokka', '1h, keittiö...', 'kt', '40,00', '293000', '7325', '1906', '3/5', 'no', 'good', 'own', 'F2018']
# ['Kallio', '1 h, avok., mak...', 'kt', '21,00', '140000', '6667', '1932', '1/3', 'no', 'poor', 'own', 'E2007']
# ['Malminkartano', '1h, avok, alkov...', 'kt', '23,50', '128000', '5447', '2017', '3/3', 'yes', 'good', 'rent', 'C2018']
# ['Kallio', '1h, kk', 'kt', '26,50', '169000', '6377', '1961', '4/6', 'yes', 'average', 'own', 'E2007']
# ['Alppila', '1h, alk, kk, 2v...', 'kt', '32,00', '195001', '6094', '1958', '4/7', 'yes', 'poor', 'own', 'F2013']
# ['Lauttasaari', '1h, ikkunalline...', 'kt', '28,00', '196000', '7000', '1961', '4/5', 'yes', 'good', 'own', 'E2007']
# ['Kruunuvuorenranta', '1h, kt, kph, ra...', 'kt', '31,00', '161000', '5194', '2016', '2/5', 'yes', 'good', 'rent', 'C2013']
# ['Vuosaari', '1h, kk, alkovi,...', 'kt', '26,50', '104000', '3925', '1965', '3/3', 'no', 'good', 'own', 'E2013']
# ['Töölö', '1h,kk', 'kt', '33,00', '275000', '8333', '1928', '4/5', 'yes', 'average', 'own', 'E2018']
# ['Punavuori', '1h,avok,vh,kh (...', 'kt', '31,50', '243000', '7714', '1930', '2/5', 'yes', 'average', 'own', 'E2007']
# ['Etu-töölö', '1h, avok, kph/w...', 'kt', '25,00', '235963', '9439', '1925', '2/6', 'yes', 'good', 'own', 'E2007']
# ['Alppila', '1h + avok + kph', 'kt', '39,10', '265000', '6777', '1912', '3/4', 'no', 'good', 'own', 'F2007']
# ['Kamppi', '1h, avok, kph/w...', 'kt', '18,40', '185000', '10054', '1873', '4/5', 'no', 'good', 'own', '']
# ['Maunula', '1h, kk, kph', 'kt', '30,00', '90000', '3000', '1962', '3/4', 'yes', 'poor', 'rent', 'E2013']
# ['Etelä-haaga', '1 h, kk, kph', 'kt', '27,00', '145000', '5370', '1956', '4/4', 'no', 'average', 'own', 'D2007']
# ['Kannelmäki', '1h+k+kph+lasite...', 'kt', '29,00', '125000', '4310', '1960', '1/3', 'no', 'good', 'rent', 'E2018']
# ['Kallio', '1h, avok, kph', 'kt', '31,00', '218000', '7032', '1909', '5/5', 'no', 'average', 'own', 'D2018']
# ['Pasila', '1h, kt, kph, la...', 'kt', '23,00', '145000', '6304', '2022', '1/5', 'yes', 'good', 'rent', 'B2018']
# ['Myllypuro', '1h+k+kph+vh+ran...', 'kt', '28,50', '66000', '2316', '1965', '4/4', 'no', 'average', 'rent', 'F2013']
# ['Sörnäinen', '1h+kk', 'kt', '26,00', '153000', '5885', '1927', '3/7', 'yes', 'average', 'own', 'E2018']
# ['Alppila', '1h, k, kph', 'kt', '35,00', '225000', '6429', '1920', '1/3', 'no', 'average', 'own', 'G2018']
# ['Oulunkylä', '1 h, kt, kh, p ...', 'kt', '27,00', '156900', '5811', '1965', '2/3', 'no', 'average', 'own', 'F2013']
# ['Taka-töölö', '1 h + kk', 'kt', '28,00', '169000', '6036', '1937', '1/6', 'yes', 'average', 'own', 'E2013']
# ['Haaga', '1h, kk, ranskal...', 'kt', '29,00', '129500', '4466', '1955', '3/3', 'no', 'average', 'own', 'G2013']
# ['Puotila', '1h, k', 'kt', '33,00', '130000', '3939', '1960', '2/3', 'no', 'good', 'rent', 'D2007']
# ['Lauttasaari', '1h, k, et, kph,...', 'kt', '33,50', '179000', '5343', '1974', '6/7', 'yes', 'poor', 'own', 'E2013']
# ['Töölö', '1h, avok, kph, ...', 'kt', '22,20', '200000', '9009', '1913', '5/5', 'no', 'average', 'own', 'F2013']
# ['Lauttasaari', '1h, avok, alkov...', 'kt', '28,00', '180000', '6429', '1950', '4/4', 'no', 'good', 'own', 'F2013']
# ['Puu-vallila', '1h+k+kph', 'rt', '31,00', '240000', '7742', '1910', '1/2', 'no', 'good', 'rent', 'D2018']
# ['Taka-töölö', '1h, k', 'kt', '29,10', '200000', '6873', '1927', '2/5', 'yes', 'good', 'own', 'D2007']
# ['Yliskylä, laajasalo', '1h+kk', 'kt', '23,00', '115000', '5000', '1966', '2/3', 'yes', 'average', 'own', 'G2013']
# ['Alppila', '1h+avok.+kph', 'kt', '24,00', '164000', '6833', '1936', '1/6', 'no', 'good', 'own', 'F2013']
# ['Punavuori', '1h, avok, kph', 'kt', '34,00', '300000', '8824', '1937', '2/5', 'yes', 'good', 'own', 'C2018']
# ['Lauttasaari', '1h, keittiö...', 'kt', '39,00', '280000', '7179', '2005', '1/6', 'yes', 'good', 'own', 'F2013']
# ['Käpylä', '1 h, kk, kph, p...', 'kt', '33,50', '145500', '4343', '1985', '1/3', 'no', 'average', 'rent', 'F2013']
# ['Puotinharju', '1h, kk, kph, ma...', 'kt', '31,00', '102000', '3290', '1963', '1/7', 'yes', 'average', 'rent', '']
# ['Mellunmäki', '1h, kk, kh, las...', 'kt', '30,50', '90000', '2951', '1982', '1/3', 'no', 'average', 'own', 'E2018']
# ['Vartiokylä', '1h,kph,k', 'kt', '31,00', '95000', '3065', '1963', '6/7', 'yes', 'poor', 'rent', 'E2007']
# ['Munkkivuori', '1h, kk, kph', 'kt', '26,00', '135000', '5192', '1960', '4/4', 'no', 'average', 'rent', 'D2018']
# ['Kallio', '1h,kk,kh', 'kt', '30,00', '173500', '5783', '1962', '2/7', 'yes', 'good', 'own', 'E2013']
# ...
# ['Pikku-huopalahti', '5h, k, kph, s, ...', 'kt', '112,50', '400120', '3557', '1991', '3/5', 'yes', 'good', 'rent', 'F2013']
# ['Tapaninkylä', '5h,k,2x wc,2x s...', 'ok', '139,20', '260000', '1868', '1951', '', 'no', 'average', 'own', 'E']
# ['Taka-töölö', '4-5h, k, kph/wc...', 'kt', '115,00', '687500', '5978', '1937', '1/6', 'yes', 'good', 'own', 'F2018']
# ['Oulunkylä', '6 h, k, kh, 3 x...', 'rt', '182,50', '435000', '2384', '1971', '1/2', 'no', 'average', 'own', 'G2007']
# ['Koskela', '4h, k, kph, eri...', 'kt', '88,00', '190000', '2159', '1973', '3/5', 'yes', 'average', 'rent', 'D2007']
# ['Länsi-pakila', '4 h, k, rh, kph...', 'ok', '95,00', '415000', '4368', '1950', '-1/2', 'no', 'good', 'rent', '']
# ['Puotila', 'Lapsi- ja perhe...', 'kt', '560,00', '700000', '1250', '1960', '1/3', 'no', 'average', 'rent', 'E2007']
# ['Hakuninmaa', '4h, k, sauna, e...', 'kt', '83,00', '250000', '3012', '1987', '2/2', 'no', 'average', 'rent', 'F2013']
# ['Länsi-pakila', '4h, k, s, 2x wc...', 'rt', '93,00', '450000', '4839', '1969', '1/2', 'no', 'good', 'own', 'D2018']
# ['Etu-töölö', '3h+k+palv.h+kph...', 'kt', '124,60', '922000', '7400', '1912', '5/5', 'yes', 'average', 'own', 'E2007']
# ['Veräjämäki', '4h, k, kph, par...', 'kt', '77,00', '305000', '3961', '1964', '1/3', 'no', 'good', 'rent', 'E2018']
# ['Länsi-pasila', '4-5h, avok,rt,k...', 'kt', '113,00', '420000', '3717', '1987', '5/5', 'yes', 'poor', 'rent', 'F2013']
# ['Aurinkolahti', '4h, k, kph, s, ...', 'rt', '89,00', '390000', '4382', '2013', '1/2', 'no', 'good', 'rent', 'C2013']
# ['Munkkiniemi', 'Yk: 2mh, kph, h...', 'rt', '152,00', '790000', '5197', '1986', '-1/3', 'no', 'good', 'own', '']
# ['Maununneva', '5h, k, ruokailu...', 'ok', '180,00', '590000', '3278', '1957', '-1/3', 'no', 'good', 'own', 'D2018']
# ['Länsi-pakila', '3-4h, k, kph, s...', 'rt', '86,50', '380000', '4393', '1978', '-1/2', 'no', 'good', 'own', 'E2018']
# ['Kontula', '4h, k', 'kt', '92,00', '140000', '1522', '1967', '4/8', 'yes', 'poor', 'rent', 'G2013']
# ['Herttoniemi', '4h+avok+rt+kph+...', 'kt', '90,00', '380000', '4222', '2023', '2/5', 'yes', 'good', 'rent', 'B2018']
# ['44', '', '44', '']
# ['', '44', '']
# []
# ['45', '', '45', '']
# ['', '45', '']
# ['4 rooms or more']
# ['Vartiokylä', '4 h+k++kph+vh+w...', 'rt', '100,00', '495000', '4950', '2019', '2/2', 'no', 'good', 'own', '']
# ['Töyrynummi', '7h, 2k, kk, 2kp...', 'ok', '200,00', '250000', '1250', '1956', '-1/2', 'no', 'average', 'own', '']
# ['Ruoholahti', '4 h, k, kh, eri...', 'kt', '108,00', '750000', '6944', '1996', '7/7', 'yes', 'average', 'own', 'E2013']
# ['Etelä-haaga', '4h, askarteluhu...', 'rt', '109,00', '512000', '4697', '1959', '2/2', 'no', 'average', 'rent', 'F2007']
# ['Roihuvuori', '4h+k', 'kt', '84,00', '310000', '3690', '1966', '1/3', 'no', 'poor', 'own', 'F2013']
# ['Pihlajamäki', '4h+k+s+erill.wc...', 'rt', '82,00', '290000', '3537', '2007', '1/2', 'no', 'good', 'own', 'C2018']
# ['Länsi-pakila', '6h, k, halli, k...', 'ok', '200,00', '650000', '3250', '1931', '2/2', 'no', 'average', 'own', 'D2018']
# ['Ullanlinna', '4h,k', 'kt', '103,00', '750000', '7282', '1926', '2/5', 'yes', 'average', 'own', 'E2007']
# ['Länsi-pakila', '6h, k, kph, s, ...', 'rt', '150,50', '370000', '2458', '1972', '1/1', 'no', 'good', 'own', 'D']
# ['Kontula', '4h, k, wc, kph,...', 'kt', '87,50', '182000', '2080', '1967', '2/3', 'no', 'good', 'rent', 'G2013']
# ['Puistola', '4h+k+kphX2+s+er...', 'rt', '96,50', '310000', '3212', '1991', '-1/2', 'no', 'good', 'own', '']
# ['Jätkäsaari', '4h, avok, kph, ...', 'kt', '84,00', '640000', '7619', '2018', '6/6', 'yes', 'good', 'own', 'B2018']
# ['Vuosaari', '4-5h, k, kph, s...', 'rt', '99,50', '230000', '2312', '1965', '1/2', 'no', 'average', 'own', 'D2018']
# ['Aurinkolahti', '5h, k, kph, s, ...', 'kt', '118,50', '485000', '4093', '2004', '2/6', 'yes', 'good', 'own', 'F2013']
# ['Länsi-pakila', '4h+k+kph+s+wc+v...', 'rt', '90,00', '396000', '4400', '1972', '1/1', 'no', 'average', 'own', 'F2007']
# ['Vartiokylä', '5h, k, kph, s, ...', 'ok', '116,00', '640000', '5517', '2020', '-1/1', 'no', 'good', 'own', 'A2018']
# ['Ruskeasuo', '4h, avokeitti&#...', 'kt', '86,00', '504000', '5860', '1951', '2/3', 'no', 'average', 'own', 'G2013']
# ['Etelä-haaga', '5h+k+halli+saun...', 'rt', '197,00', '650000', '3299', '1959', '-1/2', 'no', 'average', 'own', '']
# ['Lauttasaari', '4h, k, parveke', 'kt', '73,00', '519000', '7110', '1960', '5/5', 'yes', 'good', 'own', 'E2013']
# ['Pihlajamäki', '4h, k, kph/wc, ...', 'kt', '81,50', '184528', '2264', '1963', '3/3', 'no', 'good', 'rent', 'E2007']
# ['Vartiokylä', '4 h, avok, saun...', 'rt', '86,00', '440000', '5116', '2019', '', 'no', 'good', 'own', 'B2018']
# ['Munkkiniemi', '5 h, k, halli, ...', 'kt', '96,00', '558000', '5813', '1936', '5/6', 'yes', 'average', 'own', 'F2013']
# ['Munkkiniemi', '4 h, halli, avo...', 'kt', '127,00', '915000', '7205', '1939', '3/4', 'yes', 'good', 'own', 'D2018']
# ['Kruunuvuorenranta', '4h+avok+s+erill...', 'kt', '78,00', '465000', '5962', '2021', '3/6', 'yes', 'good', 'own', 'B2018']
# ['Tapaninvainio', '4h+k+s+kph+wc+v...', 'rt', '82,00', '270000', '3293', '1976', '1/1', 'no', 'good', 'own', '']
# ['Myllypuro', '4h, k, kph, eri...', 'kt', '87,50', '290000', '3314', '2010', '2/5', 'yes', 'good', 'rent', 'D2013']
# ['Meri-rastila', '4h + k + 2 x kp...', 'kt', '89,00', '217500', '2444', '1991', '2/3', 'no', 'good', 'rent', 'E2007']
# ['Viikki', '4h, kk, kph, s,...', 'rt', '93,50', '415000', '4439', '2004', '1/2', 'no', 'good', 'own', 'D2018']
# ['Kruununhaka', '4h, k, halli, ph', 'kt', '138,10', '1050000', '7603', '1927', '6/7', 'yes', 'good', 'own', 'D2007']
# ['Siltamäki', '5h, k, kph, eri...', 'kt', '111,50', '110000', '987', '1968', '3/3', 'no', 'average', 'own', 'F2013']
# ['Etu-töölö', '4h, avokeitti&#...</td>\n\t\t\t\t\t\t\t<td class="houseType">kt</td>\n\t\t\t\t\t\t\t<td class="cellAlignRight">124,00</td>\n\t\t\t\t\t\t\t<td class="cellAlignRight">1045000</td>\n\t\t\t\t\t\t\t<td class="cellAlignRight">8427</td>\n\t\t\t\t\t\t\t<td class="cellAlignRight">1926</td>\n\t\t\t\t\t\t\t<td>3/7</td>\n\t\t\t\t\t\t\t<td>yes</td>\n\t\t\t\t\t\t\t<td>good</td>\n\t\t\t\t\t\t\t<td>own</td>\n\t\t\t\t\t\t\t<td>C<sub>2007</sub></td>\n\t\t\t\t\t\t</tr>\n\t\t\t\t\t\t<tr>\n\t\t\t\t\t\t\t<td class="neighborhood">Kuninkaantammi</td>\n\t\t\t\t\t\t\t<td>4h+k+kph+s+eril...</td>\n\t\t\t\t\t\t\t<td class="houseType">kt</td>\n\t\t\t\t\t\t\t<td class="cellAlignRight">90,50</td>\n\t\t\t\t\t\t\t<td class="cellAlignRight">280000</td>\n\t\t\t\t\t\t\t<td class="cellAlignRight">3094</td>\n\t\t\t\t\t\t\t<td class="cellAlignRight">2018</td>\n\t\t\t\t\t\t\t<td>1/4</td>\n\t\t\t\t\t\t\t<td>yes</td>\n\t\t\t\t\t\t\t<td>good</td>\n\t\t\t\t\t\t\t<td>&#160;</td>\n\t\t\t\t\t\t\t<td>C<sub>2013</sub></td>\n\t\t\t\t\t\t</tr>\n\t\t\t\t\t\t<tr>\n\t\t\t\t\t\t\t<td class="neighborhood">Torpparinm&#228;ki</td>\n\t\t\t\t\t\t\t<td>5 h + k + s + 2...</td>\n\t\t\t\t\t\t\t<td class="houseType">ok</td>\n\t\t\t\t\t\t\t<td class="cellAlignRight">134,00</td>\n\t\t\t\t\t\t\t<td class="cellAlignRight">385000</td>\n\t\t\t\t\t\t\t<td class="cellAlignRight">2873</td>\n\t\t\t\t\t\t\t<td class="cellAlignRight">1983</td>\n\t\t\t\t\t\t\t<td>1/2</td>\n\t\t\t\t\t\t\t<td>no</td>\n\t\t\t\t\t\t\t<td>average</td>\n\t\t\t\t\t\t\t<td>rent</td>\n\t\t\t\t\t\t\t<td>D<sub>2018</sub></td>\n\t\t\t\t\t\t</tr>\n\t\t\t\t\t\t<tr>\n\t\t\t\t\t\t\t<td class="neighborhood">Mets&#228;l&#228;</td>\n\t\t\t\t\t\t\t<td>5h, k, 2x kph, ...</td>\n\t\t\t\t\t\t\t<td class="houseType">rt</td>\n\t\t\t\t\t\t\t<td class="cellAlignRight">130,00</td>\n\t\t\t\t\t\t\t<td class="cellAlignRight">542676</td>\n\t\t\t\t\t\t\t<td class="cellAlignRight">4174</td>\n\t\t\t\t\t\t\t<td class="cellAlignRight">1997</td>\n\t\t\t\t\t\t\t<td>-1/2</td>\n\t\t\t\t\t\t\t<td>no</td>\n\t\t\t\t\t\t\t<td>good</td>\n\t\t\t\t\t\t\t<td>own</td>\n\t\t\t\t\t\t\t<td>D<sub>2018</sub></td>\n\t\t\t\t\t\t</tr>\n\t\t\t\t\t\t<tr>\n\t\t\t\t\t\t\t<td class="neighborhood">Pit&#228;j&#228;nm&#228;ki</td>\n\t\t\t\t\t\t\t<td>4h, k,2xkph,khh...</td>\n\t\t\t\t\t\t\t<td class="houseType">rt</td>\n\t\t\t\t\t\t\t<td class="cellAlignRight">87,00</td>\n\t\t\t\t\t\t\t<td class="cellAlignRight">496248</td>\n\t\t\t\t\t\t\t<td class="cellAlignRight">5704</td>\n\t\t\t\t\t\t\t<td class="cellAlignRight">2023</td>\n\t\t\t\t\t\t\t<td>2/2</td>\n\t\t\t\t\t\t\t<td>no</td>\n\t\t\t\t\t\t\t<td>good</td>\n\t\t\t\t\t\t\t<td>rent</td>\n\t\t\t\t\t\t\t<td>B<sub>2018</sub></td>\n\t\t\t\t\t\t</tr>\n\t\t\t\t\t\t<tr>\n\t\t\t\t\t\t\t<td class="neighborhood">Puistola</td>\n\t\t\t\t\t\t\t<td>5h+k+wc+kph+khh...</td>\n\t\t\t\t\t\t\t<td class="houseType">rt</td>\n\t\t\t\t\t\t\t<td class="cellAlignRight">130,00</td>\n\t\t\t\t\t\t\t<td class="cellAlignRight">340000</td>\n\t\t\t\t\t\t\t<td class="cellAlignRight">2615</td>\n\t\t\t\t\t\t\t<td class="cellAlignRight">1986</td>\n\t\t\t\t\t\t\t<td>2/2</td>\n\t\t\t\t\t\t\t<td>no</td>\n\t\t\t\t\t\t\t<td>average</td>\n\t\t\t\t\t\t\t<td>own</td>\n\t\t\t\t\t\t\t<td></td>\n\t\t\t\t\t\t</tr>\n\t\t\t\t\t\t<tr>\n\t\t\t\t\t\t\t<td class="neighborhood">Heikinlaakso</td>\n\t\t\t\t\t\t\t<td>4h, kk, s/ph/kh...</td>\n\t\t\t\t\t\t\t<td class="houseType">rt</td>\n\t\t\t\t\t\t\t<td class="cellAlignRight">88,50</td>\n\t\t\t\t\t\t\t<td class="cellAlignRight">252000</td>\n\t\t\t\t\t\t\t<td class="cellAlignRight">2847</td>\n\t\t\t\t\t\t\t<td class="cellAlignRight">1986</td>\n\t\t\t\t\t\t\t<td>1/1</td>\n\t\t\t\t\t\t\t<td>no</td>\n\t\t\t\t\t\t\t<td>average</td>\n\t\t\t\t\t\t\t<td>own</td>\n\t\t\t\t\t\t\t<td>E<sub>2013</sub></td>\n\t\t\t\t\t\t</tr>\n\t\t\t\t\t\t<tr>\n\t\t\t\t\t\t\t<td class="neighborhood">Vartiokyl&#228;</td>\n\t\t\t\t\t\t\t<td>4-5h, k, saunao...</td>\n\t\t\t\t\t\t\t<td class="houseType">ok</td>\n\t\t\t\t\t\t\t<td class="cellAlignRight">140,00</td>\n ...
# []
# ['46', '', '46', '']
# ['', '46', '']
# ['4 rooms or more']
# ['Torpparinmäki', '4h, k, kph, s, ...', 'rt', '99,00', '350000', '3535', '1981', '1/2', 'no', 'good', 'rent', 'D2013']
# ['Pihlajamäki', '3-4 h,k', 'kt', '68,00', '140000', '2059', '1963', '3/4', 'no', 'average', 'rent', 'D2018']
# ['Pihlajamäki', '3mh+kph/s+k+rt+...', 'rt', '87,50', '230000', '2629', '1981', '2/2', 'no', 'good', 'own', 'D2007']
# ['Roihuvuori', '3 mh+oh+k+kph+2...', 'kt', '85,00', '400000', '4706', '1963', '3/3', 'no', 'good', 'own', 'G2007']
# ['Jätkäsaari', '4h, avok, rt, s...', 'kt', '107,50', '950000', '8837', '2020', '6/6', 'yes', 'good', 'own', 'B2018']
# ['Töölö', '4h+k+kph+wc (yj...', 'kt', '119,00', '795000', '6681', '1939', '2/3', 'no', 'good', 'own', 'E2018']
# ['Torpparinmäki', '4 h, k, kph/kh-...', 'rt', '89,50', '285000', '3184', '1988', '2/2', 'no', 'good', 'rent', 'D2018']
# ['Munkkiniemi', '4h, k, kph, vh,...', 'rt', '188,00', '940000', '5000', '1999', '1/3', 'no', 'average', 'own', '']
# ['Lauttasaari', '4-5h, k, kph, w...', 'kt', '96,00', '655000', '6823', '2017', '2/7', 'yes', 'good', 'own', 'C2013']
# ['Lauttasaari', '4-5h, k, kph, w...', 'kt', '96,00', '655000', '6823', '2017', '2/7', 'yes', 'good', 'own', 'C2013']
# ['Pasila', '4h, k, sauna, t...', 'kt', '126,50', '560000', '4427', '2004', '-1/9', 'yes', 'good', 'rent', 'F2013']
# ['Merihaka', '4h+k', 'kt', '80,50', '330000', '4099', '1974', '6/14', 'yes', 'good', 'own', 'E2018']
# ['Munkkiniemi', '4h,k,kh,p', 'kt', '82,00', '470000', '5732', '1959', '1/4', 'yes', 'average', 'own', 'G2013']
# ['Puotinharju', '4h, k, kph, par...', 'kt', '84,00', '140000', '1667', '1962', '2/3', 'no', 'average', 'rent', 'E2007']
# ['Itäkeskus', '4-5 h, avok, kp...', 'kt', '104,50', '290000', '2775', '1981', '3/4', 'yes', 'good', 'rent', 'D2018']
# ['Itä-pakila', '4h+k+kph+s+wc+k...', 'rt', '111,00', '320000', '2883', '1971', '1/1', 'no', 'good', 'own', 'C2018']
# ['Konala', '4h,k,kph,eril.w...', 'kt', '77,00', '270000', '3506', '1970', '2/4', 'yes', 'good', 'own', 'D2018']
# ['Vuosaari', '4 h, k, s, parv...', 'rt', '93,50', '289000', '3091', '2005', '-1/2', 'no', 'average', 'rent', 'C2018']
# ['Länsi-pakila', '6 h, k, rh, 2kp...', 'ok', '164,00', '470000', '2866', '1960', '-1/2', 'no', 'good', 'own', 'E2018']
# ['Tammisalo', '4-5h+kt+s+teras...', 'rt', '98,00', '793000', '8092', '2024', '-1/2', 'no', 'good', '', 'B2018']
# ['Marjaniemi', '5H+K+RT', 'rt', '135,00', '380000', '2815', '1973', '1/1', 'no', 'average', 'own', 'F2013']
# ['Aurinkolahti', '5h+k+kph+s+wc+v...', 'kt', '123,50', '440000', '3563', '2005', '2/6', 'yes', 'good', 'own', 'D2007']
# ['Lauttasaari', '5h, saarekekeit...', 'kt', '114,00', '710000', '6228', '1953', '3/4', 'no', 'good', 'own', 'D2018']
# ['Töyrynummi', '5-6h,ask,k,2xwc...', 'ok', '115,00', '220000', '1913', '1956', '2/2', 'no', 'average', 'own', '']
# ['Oulunkylä', '4h,k,kph,parveke', 'kt', '72,00', '316772', '4400', '1967', '3/3', 'no', 'average', 'own', '']
# ['Oulunkylä', '4h, k, kph/wc, ...', 'kt', '98,50', '270000', '2741', '1967', '2/3', 'yes', 'good', 'rent', 'E2007']
# ['Töölö', '4h, k, ph', 'kt', '150,00', '1100000', '7333', '1932', '5/5', 'yes', 'good', 'own', 'D2018']
# ['', '5h, k, kph, s, ...', 'ok', '90,00', '390000', '4333', '1947', '-1/3', 'no', 'good', 'rent', 'C']
# ['', '6h, k, rt, khh,...', 'ok', '157,00', '250000', '1592', '2009', '', 'no', 'poor', 'own', '']
# ['', '4h,k,rt,2xkph,k...', 'ok', '108,00', '417000', '3861', '2022', '-1/2', 'no', 'good', 'rent', 'B2018']
# ['', '4h, k, s', 'ok', '126,00', '410000', '3254', '2007', '1/3', 'no', '', 'own', '']
# ['', '4-5 h, k, s, 2 ...', 'ok', '117,00', '510000', '4359', '1992', '', 'no', 'average', 'rent', '']
# ['', '5 h, k, 3 x kph...', 'ok', '154,00', '560000', '3636', '1923', '1/2', 'no', 'average', 'rent', 'F2018']
# ['', 'Oh, avok, 4 mh,...', 'ok', '228,00', '520000', '2281', '2002', '-1/3', 'no', 'good', 'own', 'C2018']
# ['', '4h,k,s, 2x lasi...', 'ok', '108,50', '506000', '4664', '1986', '2/2', 'no', 'average', 'own', '']
# ['', '6h,k,s,th,khh,w...', 'ok', '140,00', '767500', '5482', '2005', '-1/3', 'no', 'good', 'own', 'B2018']
# ['', '4 h, avok., kph...', 'ok', '117,50', '680000', '5787', '2017', '-1/1', 'no', 'good', 'own', 'B2013']
# ['', '11 h, useita ke...', 'ok', '299,00', '1350000', '4515', '1919', '', 'no', 'average', 'own', '']
# ['', '4h, avok, rt, v...', 'ok', '117,00', '480000', '4103', '1998', '-1/1', 'no', 'good', 'own', 'E2018']
# ['', '6-7h, 2xk, 3xwc...', 'ok', '213,00', '284200', '1334', '1953', '-1/3', 'no', 'average', 'own', 'F2018']
# ['', '5h+k+kph+erill....', 'ok', '115,00', '265000', '2304', '1984', '1/1', 'no', 'average', 'own', '']
# ['', '5h, avok, kph, ...', 'ok', '119,80', '606000', '5058', '2014', '-1/1', 'no', 'good', 'own', 'B2013']
# ['', '4h+k+kph+s+eril...', 'ok', '143,00', '361000', '2524', '1994', '', 'no', 'average', 'own', 'D2018']
# ['', '4-5 h, takkahuo...', 'ok', '117,00', '370000', '3162', '1980', '', 'no', 'average', 'rent', 'C2018']
# ['', '4h, k, kph, s, ...', 'ok', '111,00', '485000', '4369', '2011', '-1/1', 'no', 'good', 'own', 'E2018']
# ['', 'Kerrostalo, 20 ...', 'ok', '928,00', '0', '0', '2008', '', 'no', 'good', 'rent', 'C2018']
# ['', '4h-5 h, k, s', 'ok', '65,00', '282000', '4338', '1948', '', 'no', 'average', 'rent', '']
# ['', '6 h, k, kh/s, 2...', 'ok', '142,00', '470000', '3310', '1954', '2/3', 'no', 'good', 'own', '']
# ['', '4h, k, rt, khh/...', 'ok', '111,00', '456667', '4114', '2011', '2/2', 'no', 'good', 'own', 'B2018']
# ['', '4 h, k, kph/2wc...', 'ok', '147,00', '525000', '3571', '1993', '-1/1', 'no', 'good', 'own', 'D2018']
# ['', '4h, k, rt, s, k...', 'ok', '94,00', '275000', '2926', '1954', '-1/2', 'no', 'average', 'own', '']
# ['', '5h+k+saunaosast...', 'ok', '130,00', '390000', '3000', '1997', '-1/2', 'no', 'good', 'own', '']
# ['46', '', '46', '']
# ['', '46', '']
# []
# ['47', '', '47', '']
# ['', '47', '']
# ['4 rooms or more']
# ['', '5h,k,pesuh,s,kh...', 'ok', '108,00', '320000', '2963', '1990', '-1/2', 'no', 'average', 'rent', 'E2018']
# ['', '5 h+k+p+s+at+ku...', 'ok', '120,00', '352000', '2933', '1956', '', 'no', 'poor', 'own', '']
# ['', '5h, k, rt, 2 kp...', 'ok', '154,00', '485000', '3149', '1950', '', 'no', 'average', 'rent', 'D2018']
# ['', '4h+k+2kph+khh+s...', 'ok', '128,00', '455000', '3555', '2005', '2/2', 'no', 'good', 'own', 'B2018']
# ['47', '', '47', '']
# ['', '47', '']

# %%
# Now, I want the headers too.
# I need them only from the first page.

header = soup.select("thead th")
# header

# I call the headers 'column_names' 
# Finding them with list comprehension
column_names = [ cell.text.strip() for cell in header ]
#print it out
column_names

# I want also substitude " ◄" with nothing "", so I need to do some cleaning.
# I make a new variable and use lambda to replace ' ◄'.
# 'map' means that lambda function is used in every list member.
# 'list' returns result into a list again.
# .strip cleans extra whitespaces away.
cleaned_headers = list(map(lambda x: x.replace(' ◄', '').strip(), column_names))

cleaned_headers
# Out:
# ['District',
#  'Apartment',
#  'Type of building',
#  'm2',
#  'Debt-free price',
#  '€/m2',
#  'Construction year',
#  'Floor',
#  'Elevator',
#  'Condition',
#  'Plot',
#  'Energy class']

# %%
# Let's turn 'column_names' and 'collected_data' into a pandas dataframe

df = pd.DataFrame(collected_data, columns = cleaned_headers)
df
# Out:
#               District           Apartment Type of building      m2  \
# 0                 None                None             None    None
# 1                    1                                    1
# 2                                        1                     None
# 3     Studio apartment                None             None    None
# 4           Itä-pasila        1h,kt,alkovi               kt   34,00
# ...                ...                 ...              ...     ...
# 2426                    5 h+k+p+s+at+ku...               ok  120,00
# 2427                    5h, k, rt, 2 kp...               ok  154,00
# 2428                    4h+k+2kph+khh+s...               ok  128,00
# 2429                47                                   47
# 2430                                    47                     None
#
#      Debt-free price  €/m2 Construction year Floor Elevator Condition  Plot  \
# 0               None  None              None  None     None      None  None
# 1               None  None              None  None     None      None  None
# 2               None  None              None  None     None      None  None
# 3               None  None              None  None     None      None  None
# 4             283000  8324              2020   3/6      yes      good   own
# ...              ...   ...               ...   ...      ...       ...   ...
# 2426          352000  2933              1956             no      poor   own
# 2427          485000  3149              1950             no   average  rent
# 2428          455000  3555              2005   2/2       no      good   own
# 2429            None  None              None  None     None      None  None
# 2430            None  None              None  None     None      None  None
#
#      Energy class
# 0            None
# 1            None
# 2            None
# 3            None
# 4           C2013
# ...           ...
# 2426
# 2427        D2018
# 2428        B2018
# 2429         None
# 2430         None
#
# [2431 rows x 12 columns]

# %%
# Let's do couple routine checkings.

# Check the data types
df.dtypes

# All data types are still objects. Need to change them later.
# Out:
# District             object
# Apartment            object
# Type of building     object
# m2                   object
# Debt-free price      object
# €/m2                 object
# Construction year    object
# Floor                object
# Elevator             object
# Condition            object
# Plot                 object
# Energy class         object
# dtype: object

# %%
len(df)
# My data has 2431 rows in the beginng. 
# This matches with number seen in down left corner of 'df' (see above).
# Out:
# 2431

# %% [markdown]
# PART 2: CLEANING THE DATA

# %% [markdown]
# Now, I have the data of apartments that have been registered into the service during last 12 months.
# My data was gathered on July 20, 2024.
#
# To be able to use the data, I need to clean it first. Following steps need to be done:
# - Change 'Debt free price' into integer.
# - Remove rows on which column 'Debt free price' is 'None'. This eliminates rows that do not include interesting information.
# - If 'Apartment' starts with '1', make a new column 'Apartment_type' and write down there 'studio'.
# - Do the same thing with 'Apartment' with 2 (two-room), 3 (three-room), 4 (four-room), >=5 (five-room or bigger)
# -
#
# Save all changes into 'df_cleaned'.
# Check number of row, len(df_cleaned).

# %%
# I want to check from how many rows 'Debt-free price' is missing, meaning that it equals 'None'.

missing_price = df[df['Debt-free price'].isna()]
# missing_price.head()

print(f'Debt-free price is missing from {len(missing_price)} rows.')
# Out:
# Debt-free price is missing from 275 rows.

# %%
df1 = df.copy()

# %%
# I remove all rows with 'None' in 'Debt-free price' and save new df in 'df_cleaned'.

df1 = df.dropna(subset=['Debt-free price'])
df1
# Out:
#            District           Apartment Type of building      m2  \
# 4        Itä-pasila        1h,kt,alkovi               kt   34,00
# 5            Kallio     1h+k+alkovi+kph               kt   37,50
# 6     Tapaninvainio  1h, kk, kh, ter...               kt   24,00
# 7            Kallio     1h, kk, kph, vh               kt   28,00
# 8         Hakaniemi                1h+k               kt   36,00
# ...             ...                 ...              ...     ...
# 2418                 5h+k+saunaosast...               ok  130,00
# 2425                 5h,k,pesuh,s,kh...               ok  108,00
# 2426                 5 h+k+p+s+at+ku...               ok  120,00
# 2427                 5h, k, rt, 2 kp...               ok  154,00
# 2428                 4h+k+2kph+khh+s...               ok  128,00
#
#      Debt-free price  €/m2 Construction year Floor Elevator Condition  Plot  \
# 4             283000  8324              2020   3/6      yes      good   own
# 5             276000  7360              1926   4/7      yes      good   own
# 6              64000  2667              1964   1/2       no   average   own
# 7             170000  6071              1962   4/7      yes      good   own
# 8             190000  5278              1989   2/8      yes             own
# ...              ...   ...               ...   ...      ...       ...   ...
# 2418          390000  3000              1997  -1/2       no      good   own
# 2425          320000  2963              1990  -1/2       no   average  rent
# 2426          352000  2933              1956             no      poor   own
# 2427          485000  3149              1950             no   average  rent
# 2428          455000  3555              2005   2/2       no      good   own
#
#      Energy class
# 4           C2013
# 5           F2013
# 6           G2013
# 7           D2018
# 8           F2018
# ...           ...
# 2418
# 2425        E2018
# 2426
# 2427        D2018
# 2428        B2018
#
# [2156 rows x 12 columns]

# %%
# I check, if 'dropna' deleted right amount of rows.
# Result should be 2156 = 2431 (rows in df) - 275 (rows with 'None').

print(f' There are {len(df)-len(missing_price)} rows in the new data frame "df1".')
# Out:
#  There are 2156 rows in the new data frame "df1".

# %%
# On the webpage squaremeters are displayed with the Finnish way (32,00). Comma needs to be changed into dot (32.00).

df1.loc[:, 'm2'] = df1['m2'].str.replace(",", ".")
df1.head()
# Out:
#         District           Apartment Type of building     m2 Debt-free price  \
# 4     Itä-pasila        1h,kt,alkovi               kt  34.00          283000
# 5         Kallio     1h+k+alkovi+kph               kt  37.50          276000
# 6  Tapaninvainio  1h, kk, kh, ter...               kt  24.00           64000
# 7         Kallio     1h, kk, kph, vh               kt  28.00          170000
# 8      Hakaniemi                1h+k               kt  36.00          190000
#
#    €/m2 Construction year Floor Elevator Condition Plot Energy class
# 4  8324              2020   3/6      yes      good  own        C2013
# 5  7360              1926   4/7      yes      good  own        F2013
# 6  2667              1964   1/2       no   average  own        G2013
# 7  6071              1962   4/7      yes      good  own        D2018
# 8  5278              1989   2/8      yes            own        F2018

# %%
# I name a new variable that contains changes done above.
df2 = df1.copy()

# %%
# I change four columns containing numbers into int or float, depending how the numbers are formed in df above.
df2["Debt-free price"] = df2["Debt-free price"].astype(int)
df2["m2"] = df2["m2"].astype(float)
df2["Construction year"] = df2["Construction year"].astype(int)
df2["€/m2"] = df2["€/m2"].astype(int)


# Checking, if changes went through.
print(df2.dtypes)
# Out:
# District              object
# Apartment             object
# Type of building      object
# m2                   float64
# Debt-free price        int32
# €/m2                   int32
# Construction year      int32
# Floor                 object
# Elevator              object
# Condition             object
# Plot                  object
# Energy class          object
# dtype: object

# %%
# Checking, how does the df now look like.
df2.tail()
# Out:
#      District           Apartment Type of building     m2  Debt-free price  \
# 2418           5h+k+saunaosast...               ok  130.0           390000
# 2425           5h,k,pesuh,s,kh...               ok  108.0           320000
# 2426           5 h+k+p+s+at+ku...               ok  120.0           352000
# 2427           5h, k, rt, 2 kp...               ok  154.0           485000
# 2428           4h+k+2kph+khh+s...               ok  128.0           455000
#
#       €/m2  Construction year Floor Elevator Condition  Plot Energy class
# 2418  3000               1997  -1/2       no      good   own
# 2425  2963               1990  -1/2       no   average  rent        E2018
# 2426  2933               1956             no      poor   own
# 2427  3149               1950             no   average  rent        D2018
# 2428  3555               2005   2/2       no      good   own        B2018

# %%
# I want to divide 'Apartment' and form a new column called 'Apartment_type'.
# Rule for the new column: 
# If 'Apartment' starts with '1', write to the new column 'studio'.
# If it starts with '2' --> 'two-room', '3' --> 'three-room', '4' --> 'four-room', '>=5' --> 'five-rooms or bigger'

# To create the new column with conditions based on existing column, I import numpy library.
import numpy as np

# I create a list of our conditions based on which number the 'Apartment' starts.
conditions = [
    df2['Apartment'].str.startswith('1'),
    df2['Apartment'].str.startswith('2'),
    df2['Apartment'].str.startswith('3'),
    df2['Apartment'].str.startswith('4'),
]

# Here are new values for each conditions. These will be set into 'Apartment_type'.
choices = ['studio', 'two-rooms', 'three-rooms', 'four-rooms']

# I make classification 'five-rooms or bigger'.
# It will be given in 'Apartment_type' for any row not matching 'conditions'.
df2['Apartment_type'] = np.select(conditions, choices, default='five-rooms or bigger')

df2
# Out:
#            District           Apartment Type of building     m2  \
# 4        Itä-pasila        1h,kt,alkovi               kt   34.0
# 5            Kallio     1h+k+alkovi+kph               kt   37.5
# 6     Tapaninvainio  1h, kk, kh, ter...               kt   24.0
# 7            Kallio     1h, kk, kph, vh               kt   28.0
# 8         Hakaniemi                1h+k               kt   36.0
# ...             ...                 ...              ...    ...
# 2418                 5h+k+saunaosast...               ok  130.0
# 2425                 5h,k,pesuh,s,kh...               ok  108.0
# 2426                 5 h+k+p+s+at+ku...               ok  120.0
# 2427                 5h, k, rt, 2 kp...               ok  154.0
# 2428                 4h+k+2kph+khh+s...               ok  128.0
#
#       Debt-free price  €/m2  Construction year Floor Elevator Condition  Plot  \
# 4              283000  8324               2020   3/6      yes      good   own
# 5              276000  7360               1926   4/7      yes      good   own
# 6               64000  2667               1964   1/2       no   average   own
# 7              170000  6071               1962   4/7      yes      good   own
# 8              190000  5278               1989   2/8      yes             own
# ...               ...   ...                ...   ...      ...       ...   ...
# 2418           390000  3000               1997  -1/2       no      good   own
# 2425           320000  2963               1990  -1/2       no   average  rent
# 2426           352000  2933               1956             no      poor   own
# 2427           485000  3149               1950             no   average  rent
# 2428           455000  3555               2005   2/2       no      good   own
#
#      Energy class        Apartment_type
# 4           C2013                studio
# 5           F2013                studio
# 6           G2013                studio
# 7           D2018                studio
# 8           F2018                studio
# ...           ...                   ...
# 2418               five-rooms or bigger
# 2425        E2018  five-rooms or bigger
# 2426               five-rooms or bigger
# 2427        D2018  five-rooms or bigger
# 2428        B2018            four-rooms
#
# [2156 rows x 13 columns]

# %%
# Checking how many different 'Apartment_type' there are. 
# Most common is two-room, most rare five-rooms or bigger. This sounds plausible, so I continue.
df2.Apartment_type.value_counts()
# Out:
# Apartment_type
# two-rooms               755
# three-rooms             583
# studio                  374
# four-rooms              305
# five-rooms or bigger    139
# Name: count, dtype: int64

# %%
# I want to check are there in my 'five-rooms or bigger' classification apartments from wrong categories.

df2['Apartment'] = df2['Apartment'].astype(str)

# I don't want on my checklist rows starting with numbers, only the wrong ones that start with something else.
# I create variable that I can use to exclude all right answers.
# I just guess, there are no apartments bigger than 12-rooms, so I make variable including numbers from 5 to 12.
prefixes = ('5', '6', '7', '8', '9', '10', '11', '12')

checklist = df2.loc[
    (df2['Apartment_type'] == 'five-rooms or bigger') & 
    # '~' turns my command meaning opposite than I am writing
    # This is why code below returns rows, that DO NOT start with any 'prefixes' given above.
    (~df2['Apartment'].apply(lambda x: any(str(x).startswith(prefix) for prefix in prefixes))),
    'Apartment'
]

print(f'There are {len(checklist)} apartments that do not fulfill definition of 5-room or bigger apartments.')
print("-----------")
print(f'Here are the cases: {checklist}')
print("-----------")
# Out:
# There are 17 apartments that do not fulfill definition of 5-room or bigger apartments.
# -----------
# Here are the cases: 132      Studio, avok, kph
# 142     huone, avokeitt...
# 179     i h, k, kh (Yj ...
# 239         huone, kk, kph
# 1177    Oh, avok, mh, k...
# 1494      Oh+avokeitti...
# 1891         Yläkerta: ...
# 1903      AK: k/oh, ty...
# 1907    ak: oh, avokeit...
# 1921    oh, k, 5 x mh, ...
# 2092    Oh, kt, 3mh, vh...
# 2203    Ak: 2h, k, ruok...
# 2230    Olohuone, keitt...
# 2314    Lapsi- ja perhe...
# 2321    Yk: 2mh, kph, h...
# 2400    Oh, avok, 4 mh,...
# 2412    Kerrostalo, 20 ...
# Name: Apartment, dtype: object
# -----------

# %%
# I make a new dataframe 'df3' that do not contain 'checklist' rows.
df3 = df2[~df2['Apartment'].isin(checklist)]
df3.head()
# Out:
#         District           Apartment Type of building    m2  Debt-free price  \
# 4     Itä-pasila        1h,kt,alkovi               kt  34.0           283000
# 5         Kallio     1h+k+alkovi+kph               kt  37.5           276000
# 6  Tapaninvainio  1h, kk, kh, ter...               kt  24.0            64000
# 7         Kallio     1h, kk, kph, vh               kt  28.0           170000
# 8      Hakaniemi                1h+k               kt  36.0           190000
#
#    €/m2  Construction year Floor Elevator Condition Plot Energy class  \
# 4  8324               2020   3/6      yes      good  own        C2013
# 5  7360               1926   4/7      yes      good  own        F2013
# 6  2667               1964   1/2       no   average  own        G2013
# 7  6071               1962   4/7      yes      good  own        D2018
# 8  5278               1989   2/8      yes            own        F2018
#
#   Apartment_type
# 4         studio
# 5         studio
# 6         studio
# 7         studio
# 8         studio

# %%
# Checking, if the code really dropped 17 rows off my df.
len(df3) - len(df2)
# Out:
# -17

# %%
# Are there rows that are totally equal? 
# This is important to know, so that I can be sure, there are no duplicates. 
# It would be weird to have exatly same kind of apartments in the df, because there are so many parameters in the data.
# If there are duplicates, leave only one row.

# Are there duplicates? True = yes.
duplicates = df3.duplicated()
print(duplicates.value_counts())

print('-----------')

# There is one duplicate. How does it look like?
duplicate_row = df3[df3.duplicated()]
print('This is how the duplicate row looks like:')
print(duplicate_row)
print(f'There are {len(df3)} rows in df3.')

print('-----------')

# I delete it and make a new dataframe 'df_cleaned'.
df_cleaned = df3.drop_duplicates()

# Checking that there is now one row less.
print(f'There are {len(df_cleaned)} rows in the df_cleaned.')
# Out:
# False    2138
# True        1
# Name: count, dtype: int64
# -----------
# This is how the duplicate row looks like:
#          District           Apartment Type of building    m2  Debt-free price  \
# 2376  Lauttasaari  4-5h, k, kph, w...               kt  96.0           655000
#
#       €/m2  Construction year Floor Elevator Condition Plot Energy class  \
# 2376  6823               2017   2/7      yes      good  own        C2013
#
#      Apartment_type
# 2376     four-rooms
# There are 2139 rows in df3.
# -----------
# There are 2138 rows in the df_cleaned.

# %% [markdown]
# Now the data is enough clean for analyzing.
# One cleaning thing could be still to drop out rows missing 'District'. For now, I want to keep them, because I want to ask questions about whole Helsinki, so the district does not matter yet.

# %% [markdown]
# PART 3: INTERVIEWING THE DATA
#
# Interesting questions to ask:
# 1) Whole city
# - Most expensive and cheapest apartments (Debt-free price)?
# - Average square meter price (€/m2) in Helsinki?
# - Smallest and biggest apartment?
# - How many apartments have been sold?
# - What are the Type of buildings? How many
#
# 2) District
# - How many districts there are?
# - How many apartments have been sold from each district?
# - Which districts (top 10) are most represented in the data? = From which areas apartments have been sold most, according to this data?
# - New dataframe: 'Apartment_type' per distict? --> I want to compare where there have been studios vs. big apartments sold?
#
# 3) Notice:
# It would be nice to make a map out of this, but it will be difficult, because Datawrapper's choropleth map holds different district division (boroughs vs. here mishmash created by real estate brokers). --> If I clean data well, I can try.
# Map
# - €/m2 by district --> Comparing neighboring boroughs
# - Flats sold by area --> tooltip about studio, two-rooms, three-rooms etc.

# %%
# Most expensive and cheapest apartments (Debt-free price)?

most_exp_aprt = df_cleaned["Debt-free price"].max()
print(f'Most expensive apartment has costed {most_exp_aprt} euros.')

print('- - - - - - - - - -')

cheapest_apart = df_cleaned["Debt-free price"].min()
print(f'Most cheapest apartment has costed {cheapest_apart} euros.')

print('- - - - - - - - - -')

# How many times more the most expesive apartment has costed vs. the cheapest?
print(f'The most expensive apartments sold in Helsinki costed {round(most_exp_aprt/cheapest_apart)} times as much as the most cheapest apartment sold.')

print('- - - - - - - - - -')

# Where were these apartments located?

max_price_index = df_cleaned['Debt-free price'].idxmax()
max_price_district = df_cleaned.loc[max_price_index, 'District']
print(f'The most expensive apartment was sold in {max_price_district}.')

print('- - - - - - - - - -')

min_price_index = df_cleaned['Debt-free price'].idxmin()
min_price_district = df_cleaned.loc[min_price_index, 'District']
print(f'The cheapest apartment was located in {min_price_district}.')

print('- - - - - - - - - -')

# How big were they?

max_price_size = df_cleaned.loc[max_price_index, 'm2']
print(f'The size of the most expensive apartment was {max_price_size} m2.')

print('- - - - - - - - - -')

min_price_size = df_cleaned.loc[min_price_index, 'm2']
print(f'The size of the cheapest apartment was {min_price_size} m2.')

# Print the whole data row.
min_price_row = df_cleaned.loc[min_price_index]
max_price_row = df_cleaned.loc[max_price_index]

print('- - - - - - - - - -')

print('HERE IS ALL INFORMATION ABOUT THE MOST EXPENSIVE:')
print(max_price_row)

print('- - - - - - - - - -')

print('HERE IS ALL INFORMATION ABOUT THE CHEAPEST:')
print(min_price_row)
# Out:
# Most expensive apartment has costed 2100000 euros.
# - - - - - - - - - -
# Most cheapest apartment has costed 43000 euros.
# - - - - - - - - - -
# The most expensive apartments sold in Helsinki costed 49 times as much as the most cheapest apartment sold.
# - - - - - - - - - -
# The most expensive apartment was sold in Ullanlinna.
# - - - - - - - - - -
# The cheapest apartment was located in Koskela.
# - - - - - - - - - -
# The size of the most expensive apartment was 201.5 m2.
# - - - - - - - - - -
# The size of the cheapest apartment was 42.5 m2.
# - - - - - - - - - -
# HERE IS ALL INFORMATION ABOUT THE MOST EXPENSIVE:
# District                       Ullanlinna
# Apartment              6h, k, kph, spa...
# Type of building                       kt
# m2                                  201.5
# Debt-free price                   2100000
# €/m2                                10422
# Construction year                    1915
# Floor                                -1/5
# Elevator                               no
# Condition                            good
# Plot                                  own
# Energy class                        F2013
# Apartment_type       five-rooms or bigger
# Name: 2238, dtype: object
# - - - - - - - - - -
# HERE IS ALL INFORMATION ABOUT THE CHEAPEST:
# District                   Koskela
# Apartment            2h+avok.kph+p
# Type of building                kt
# m2                            42.5
# Debt-free price              43000
# €/m2                          1012
# Construction year             2021
# Floor                          4/5
# Elevator                       yes
# Condition                     good
# Plot                          rent
# Energy class                 B2018
# Apartment_type           two-rooms
# Name: 503, dtype: object

# %% [markdown]
# It would be nice to write a story about the cheapest and the most expensive apartments, but I do not have time for mapping.
# I decide instead to check out, have the apartments become smaller during last decades. In Finland there has been heavy discussion that construction companies are all the time building smaller and smaller apartments. For example, there can be new three-room apartments with less than 50 m2. These are criticized for being unpractical to furniture and to live in.
# Let's see, what is the average size of a studio, a two-room apartment and a three-room apartment built on different decades.
# I do some sorting, because I do not want to check every decade as a separate section. By grouping the 'Construction year' I get more results per category.
#
# SORTING:
# -1929,
# 1930-1949,
# 1950-1969,
# 1970-1989,
# 1990-2009,
# 2010-

# %%
# I create a variable 'relevant_apartments' and take in only studios, two-rooms and three rooms.
relevant_apartments = df_cleaned[df_cleaned['Apartment_type'].isin(['studio', 'two-rooms', 'three-rooms'])].copy()

# Defining categories by 'Construction year'.
def categorize_year(year):
    if year <= 1929:
        return '1929 or earlier'
    elif 1930 <= year <= 1949:
        return '1930-1949'
    elif 1950 <= year <= 1969:
        return '1950-1969'
    elif 1970 <= year <= 1989:
        return '1970-1989'
    elif 1990 <= year <= 2009:
        return '1990-2009'
    else:
        return '2010 or later'

# Making a new column 'Construction decade'.
relevant_apartments.loc[:, 'Construction decade'] = relevant_apartments['Construction year'].apply(categorize_year)

# With .agg() function (=aggregation) it is possibel to apply multiple functions to the grouped data.
# I use it, because I want to see the median size (m2) and number of data points by category.
grouped = round(relevant_apartments.groupby(['Construction decade', 'Apartment_type']).agg(
    median_m2=('m2', 'median'),
    count=('m2', 'size')
).reset_index())

print(grouped)
# Out:
#    Construction decade Apartment_type  median_m2  count
# 0      1929 or earlier         studio       32.0    107
# 1      1929 or earlier    three-rooms       80.0     44
# 2      1929 or earlier      two-rooms       53.0     86
# 3            1930-1949         studio       26.0     56
# 4            1930-1949    three-rooms       64.0     31
# 5            1930-1949      two-rooms       44.0    112
# 6            1950-1969         studio       28.0    130
# 7            1950-1969    three-rooms       67.0    186
# 8            1950-1969      two-rooms       50.0    253
# 9            1970-1989         studio       34.0     55
# 10           1970-1989    three-rooms       75.0    163
# 11           1970-1989      two-rooms       55.0    158
# 12           1990-2009         studio       38.0      8
# 13           1990-2009    three-rooms       77.0     74
# 14           1990-2009      two-rooms       52.0     68
# 15       2010 or later         studio       31.0     18
# 16       2010 or later    three-rooms       69.0     85
# 17       2010 or later      two-rooms       50.0     78

# %%
# Save results into excel file.
output_file = 'apartment_analysis.xlsx'
grouped.to_excel(output_file, index=False)
